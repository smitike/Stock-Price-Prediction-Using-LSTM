# %% [markdown]
# <a href="https://colab.research.google.com/github/smitike/Stock-Price-Prediction-Using-LSTM/blob/main/(1.47%25)lstm_improved_model_diff_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
import yfinance as yf
import pandas as pd

# Define start and end date
START = "2010-01-01"
TODAY = "2024-11-13"

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.429596  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.507843  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  286.871246  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  278.888000  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.188385  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %% [markdown]
# # Define start day to fetch the dataset from the yahoo finance library
#
# ---

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.429596  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.507843  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  286.871246  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  278.888000  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.188385  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-4-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %% [markdown]
# Visualizing Closing Price

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3663    4139.649902  4149.799805  3975.250000  4003.600098  3792017
# 3664    4150.899902  4205.799805  4085.050049  4169.700195  3724349
# 3665    4147.000000  4169.750000  4117.649902  4155.000000  1648039
# 3666    4198.700195  4234.299805  4117.649902  4128.200195  1406487
# 3667    4197.399902  4218.000000  4164.350098  4216.000000  1587640
#
# [3668 rows x 5 columns]

# %% [markdown]
# # Plotting moving averages of 100 day
#
# ---

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3663    4215.103494
# 3664    4218.291992
# 3665    4221.610991
# 3666    4225.580994
# 3667    4229.682493
#
# [3668 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %% [markdown]
# # Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
#
# ---

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3663    4079.037250
# 3664    4080.272749
# 3665    4081.701249
# 3666    4083.271749
# 3667    4084.745748
#
# [3668 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3668, 5)

# %% [markdown]
# # Spliting the dataset into training (70%) and testing (30%) set

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2567, 7)
# (1101, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  293.429596  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  293.507843  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  286.871246  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  278.888000  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  273.188385  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2567   2020-06-08 00:00:00+00:00  1950.448120  2071.750000  2095.000000
# 2568   2020-06-09 00:00:00+00:00  1950.730835  2072.050049  2095.500000
# 2569   2020-06-10 00:00:00+00:00  1985.281738  2108.750000  2132.000000
# 2570   2020-06-11 00:00:00+00:00  1946.588135  2067.649902  2105.000000
# 2571   2020-06-12 00:00:00+00:00  1920.086670  2039.500000  2049.199951
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2567    2062.100098  2078.250000  2957841
# 2568    2060.250000  2063.100098  2909439
# 2569    2073.500000  2077.050049  5168397
# 2570    2061.800049  2100.000000  2269513
# 2571    2011.000000  2011.199951  2842642

# %% [markdown]
# # Using MinMax scaler for normalization of the dataset
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01671754],
#        [0.01606246],
#        [0.01251195],
#        ...,
#        [0.87904671],
#        [0.89306534],
#        [0.88968517]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2467, 100, 1)

# %% [markdown]
# # ML Model (LSTM)
#
# ---

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Attention

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.1))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.1))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.1))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.1))

# model.add(LSTM(units=100, activation='relu', return_sequences=True))
# model.add(Dropout(0.1))


# Add Attention layer
# attention_output = Attention()([model.output, model.output])  # Self-attention on LSTM output
# model.add(Dense(units=1))

# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model
#
# ---

# %%
# from tensorflow.keras.optimizers import Adam
# model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 140ms/step - loss: 0.0963 - mean_absolute_error: 0.2133
# Epoch 2/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 0.0033 - mean_absolute_error: 0.0404
# Epoch 3/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0037 - mean_absolute_error: 0.0425
# Epoch 4/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0029 - mean_absolute_error: 0.0371
# Epoch 5/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0028 - mean_absolute_error: 0.0360
# Epoch 6/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0024 - mean_absolute_error: 0.0346
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0024 - mean_absolute_error: 0.0348
# Epoch 8/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0021 - mean_absolute_error: 0.0336
# Epoch 9/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0022 - mean_absolute_error: 0.0335
# Epoch 10/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0342
# Epoch 11/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0020 - mean_absolute_error: 0.0312
# Epoch 12/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0020 - mean_absolute_error: 0.0315
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0335
# Epoch 14/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0017 - mean_absolute_error: 0.0296
# Epoch 15/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0020 - mean_absolute_error: 0.0316
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0299
# Epoch 17/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0018 - mean_absolute_error: 0.0303
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0019 - mean_absolute_error: 0.0298
# Epoch 19/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0016 - mean_absolute_error: 0.0288
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0016 - mean_absolute_error: 0.0284
# Epoch 21/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0016 - mean_absolute_error: 0.0287
# Epoch 22/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0015 - mean_absolute_error: 0.0264
# Epoch 23/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0014 - mean_absolute_error: 0.0266
# Epoch 24/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0015 - mean_absolute_error: 0.0277
# Epoch 25/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0018 - mean_absolute_error: 0.0293
# Epoch 26/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0014 - mean_absolute_error: 0.0267
# Epoch 27/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0014 - mean_absolute_error: 0.0266
# Epoch 28/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0013 - mean_absolute_error: 0.0256
# Epoch 29/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0261
# Epoch 30/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0014 - mean_absolute_error: 0.0266
# Epoch 31/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0021 - mean_absolute_error: 0.0322
# Epoch 32/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0016 - mean_absolute_error: 0.0281
# Epoch 33/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0240
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0013 - mean_absolute_error: 0.0248
# Epoch 35/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0010 - mean_absolute_error: 0.0221
# Epoch 36/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0012 - mean_absolute_error: 0.0255
# Epoch 37/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0011 - mean_absolute_error: 0.0237
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0241
# Epoch 39/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0013 - mean_absolute_error: 0.0251
# Epoch 40/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0256
# Epoch 41/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0010 - mean_absolute_error: 0.0221
# Epoch 42/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0011 - mean_absolute_error: 0.0242
# Epoch 43/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 9.4097e-04 - mean_absolute_error: 0.0219
# Epoch 44/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0012 - mean_absolute_error: 0.0243
# Epoch 45/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0010 - mean_absolute_error: 0.0217
# Epoch 46/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0235
# Epoch 47/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 8.3734e-04 - mean_absolute_error: 0.0208
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0238
# Epoch 49/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 8.7187e-04 - mean_absolute_error: 0.0213
# Epoch 50/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0010 - mean_absolute_error: 0.0229
# Epoch 51/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 9.6022e-04 - mean_absolute_error: 0.0218
# Epoch 52/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0011 - mean_absolute_error: 0.0224
# Epoch 53/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0010 - mean_absolute_error: 0.0228
# Epoch 54/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 9.8552e-04 - mean_absolute_error: 0.0225
# Epoch 55/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 9.6188e-04 - mean_absolute_error: 0.0219
# Epoch 56/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0012 - mean_absolute_error: 0.0248
# Epoch 57/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0011 - mean_absolute_error: 0.0241
# Epoch 58/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 9.7754e-04 - mean_absolute_error: 0.0218
# Epoch 59/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.5795e-04 - mean_absolute_error: 0.0207
# Epoch 60/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.2366e-04 - mean_absolute_error: 0.0204
# Epoch 61/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0011 - mean_absolute_error: 0.0232
# Epoch 62/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 8.5872e-04 - mean_absolute_error: 0.0208
# Epoch 63/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 9.6628e-04 - mean_absolute_error: 0.0223
# Epoch 64/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0012 - mean_absolute_error: 0.0245
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 8.6366e-04 - mean_absolute_error: 0.0212
# Epoch 66/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 7.6738e-04 - mean_absolute_error: 0.0206
# Epoch 67/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 8.1758e-04 - mean_absolute_error: 0.0198
# Epoch 68/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0010 - mean_absolute_error: 0.0226
# Epoch 69/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 8.7476e-04 - mean_absolute_error: 0.0214
# Epoch 70/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0011 - mean_absolute_error: 0.0246
# Epoch 71/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 8.7412e-04 - mean_absolute_error: 0.0207
# Epoch 72/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 9.0763e-04 - mean_absolute_error: 0.0205
# Epoch 73/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 8.3036e-04 - mean_absolute_error: 0.0201
# Epoch 74/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 8.8633e-04 - mean_absolute_error: 0.0208
# Epoch 75/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 8.8102e-04 - mean_absolute_error: 0.0217
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 8.8413e-04 - mean_absolute_error: 0.0219
# Epoch 77/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 8.2011e-04 - mean_absolute_error: 0.0201
# Epoch 78/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.8756e-04 - mean_absolute_error: 0.0184
# Epoch 79/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 7.5961e-04 - mean_absolute_error: 0.0197
# Epoch 80/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 7.6743e-04 - mean_absolute_error: 0.0197
# Epoch 81/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 8.1433e-04 - mean_absolute_error: 0.0203
# Epoch 82/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 7.4718e-04 - mean_absolute_error: 0.0199
# Epoch 83/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 7.2623e-04 - mean_absolute_error: 0.0194
# Epoch 84/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 7.4677e-04 - mean_absolute_error: 0.0195
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 7.1979e-04 - mean_absolute_error: 0.0191
# Epoch 86/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 7.1479e-04 - mean_absolute_error: 0.0191
# Epoch 87/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 8.3556e-04 - mean_absolute_error: 0.0202
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 7.1133e-04 - mean_absolute_error: 0.0195
# Epoch 89/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 7.1203e-04 - mean_absolute_error: 0.0188
# Epoch 90/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 6.1086e-04 - mean_absolute_error: 0.0178
# Epoch 91/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.6850e-04 - mean_absolute_error: 0.0188
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 7.2884e-04 - mean_absolute_error: 0.0196
# Epoch 93/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.5588e-04 - mean_absolute_error: 0.0186
# Epoch 94/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.8427e-04 - mean_absolute_error: 0.0189
# Epoch 95/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 6.0881e-04 - mean_absolute_error: 0.0178
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 6.7343e-04 - mean_absolute_error: 0.0187
# Epoch 97/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.2832e-04 - mean_absolute_error: 0.0186
# Epoch 98/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 7.4016e-04 - mean_absolute_error: 0.0197
# Epoch 99/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 6.7218e-04 - mean_absolute_error: 0.0185
# Epoch 100/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 7.1414e-04 - mean_absolute_error: 0.0192

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (1101, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %% [markdown]
# **Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.**
#
# ---

# %%
# final_df = past_100_days.append(test_df, ignore_index = True)
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2202.050049
# 1  2210.000000
# 2  2208.000000
# 3  2184.699951
# 4  2195.000000

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.23154078],
#        [0.23418552],
#        [0.23352017],
#        ...,
#        [0.86881016],
#        [0.86881016],
#        [0.88434608]])

# %%
input_data.shape
# Out:
# (1201, 1)

# %% [markdown]
# # Testing the model
#
# ---

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1101, 100, 1)
# (1101,)

# %% [markdown]
# SELAM - Ensure that both the training and testing data are normalized before feeding them into the model:

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# x_train = scaler.fit_transform(x_train.reshape(-1, 1)).reshape(x_train.shape)
# x_test = scaler.transform(x_test.reshape(-1, 1)).reshape(x_test.shape)

# %% [markdown]
# # Making prediction and plotting the graph of predicted vs actual values
#
# ---

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step

# %%
# # Select the last prediction from each sequence
# y_pred_last = y_pred[:, -1, 0]  # Select the last element from the second dimension

# # Inverse transform the selected predictions
# y_pred_inverse = scaler.inverse_transform(y_pred_last.reshape(-1, 1))  # Reshape to 2D for inverse_transform

# # Scale the predictions back to original units
# scale_factor = 1 / scaler.scale_[0]  # Get the scale factor from scaler.scale_
# y_pred_scaled = y_pred_inverse * scale_factor
# y_test_scaled = y_test * scale_factor  # Scale y_test as well

# ... (Rest of the code for plotting and evaluation)

# %%
y_pred.shape
# Out:
# (1101, 1)

# %%
y_test
# Out:
# array([0.22674264, 0.22027525, 0.21942637, 0.20693626, 0.21301967,
#        0.20408655, 0.18456314, 0.15600556, 0.15168051, 0.15804685,
#        0.16130073, 0.17156772, 0.18844357, 0.20855311, 0.19060609,
#        0.19171767, 0.19020188, 0.1936175 , 0.19974127, 0.2037228 ,
#        0.20113583, 0.20087308, 0.1910103 , 0.19198042, 0.19602254,
#        0.20410678, 0.1976798 , 0.19966045, 0.19291013, 0.1904444 ,
#        0.18270378, 0.18389618, 0.1886659 , 0.20299519, 0.21461629,
#        0.2231452 , 0.20265162, 0.20725965, 0.21287816, 0.22296322,
#        0.21421207, 0.20517795, 0.20248993, 0.21623313, 0.24636715,
#        0.24582142, 0.25851374, 0.25384507, 0.26275796, 0.26758828,
#        0.27773393, 0.29266964, 0.28498962, 0.25018693, 0.24351744,
#        0.25576508, 0.25236964, 0.25467372, 0.25053055, 0.24883278,
#        0.22890522, 0.23381635, 0.23080499, 0.23603952, 0.21987104,
#        0.2411124 , 0.22997634, 0.21987104, 0.21269628, 0.21586933,
#        0.21784998, 0.23082522, 0.24590225, 0.26120171, 0.27470235,
#        0.27039753, 0.26110065, 0.257099  , 0.27464175, 0.29303339,
#        0.28818285, 0.29790417, 0.29424603, 0.29725739, 0.29311422,
#        0.29794453, 0.28535337, 0.29747973, 0.30103681, 0.30091553,
#        0.30071342, 0.2971968 , 0.28959759, 0.28317066, 0.28715209,
#        0.29343761, 0.29266964, 0.25625011, 0.25305688, 0.24192082,
#        0.22848077, 0.2344429 , 0.23729261, 0.23927321, 0.24008164,
#        0.2368884 , 0.22391316, 0.22492369, 0.22747024, 0.2410517 ,
#        0.23058266, 0.23707028, 0.23806058, 0.24141555, 0.24834775,
#        0.25914019, 0.26686067, 0.26655751, 0.27872433, 0.28513103,
#        0.28343336, 0.28814239, 0.29721703, 0.27819884, 0.26732548,
#        0.2575638 , 0.26340464, 0.26696173, 0.27332806, 0.26837647,
#        0.28612133, 0.29060812, 0.29222497, 0.28697022, 0.28947631,
#        0.28777864, 0.29543844, 0.29384182, 0.28345359, 0.2775117 ,
#        0.27233776, 0.25889772, 0.24830739, 0.24636715, 0.25075279,
#        0.24234526, 0.24539698, 0.23644373, 0.22270052, 0.18955515,
#        0.2049152 , 0.22393339, 0.2251258 , 0.2204369 , 0.22391316,
#        0.21570764, 0.21831484, 0.22187187, 0.21623313, 0.20592573,
#        0.19848822, 0.16934455, 0.18672567, 0.20883604, 0.20612784,
#        0.19937752, 0.20976574, 0.21584915, 0.22088157, 0.22443866,
#        0.22999657, 0.24363872, 0.24877219, 0.27114536, 0.29545867,
#        0.27848177, 0.27278234, 0.26797226, 0.27201438, 0.27047835,
#        0.24978272, 0.23644373, 0.24735745, 0.25895831, 0.2678712 ,
#        0.25978697, 0.2421027 , 0.23785847, 0.24307276, 0.22411527,
#        0.22076029, 0.21382809, 0.21847653, 0.22391316, 0.21817337,
#        0.20612784, 0.20370257, 0.21805209, 0.22728837, 0.24048585,
#        0.22128578, 0.20097413, 0.20238888, 0.19319306, 0.20248993,
#        0.23211868, 0.24776166, 0.26150487, 0.26738617, 0.28383757,
#        0.28454494, 0.28500975, 0.27856259, 0.27080174, 0.27124641,
#        0.26330359, 0.26190908, 0.25996884, 0.2659512 , 0.27561182,
#        0.27395461, 0.28133148, 0.28454494, 0.28373652, 0.27431836,
#        0.27848177, 0.27815838, 0.286566  , 0.28575758, 0.26279832,
#        0.26354616, 0.26987203, 0.27391415, 0.26837647, 0.26635541,
#        0.26110065, 0.26029223, 0.25018693, 0.22860206, 0.23733298,
#        0.23466524, 0.24181977, 0.24634692, 0.24776166, 0.24776166,
#        0.25932216, 0.26029223, 0.26878068, 0.26878068, 0.27654153,
#        0.27486409, 0.27666281, 0.2607975 , 0.24278984, 0.24452797,
#        0.24531616, 0.23450349, 0.19561833, 0.1938802 , 0.20451099,
#        0.20976574, 0.23363448, 0.22860206, 0.17338667, 0.16732349,
#        0.10198263, 0.        , 0.06863515, 0.0473332 , 0.04919257,
#        0.0164514 , 0.04888941, 0.04515045, 0.05125404, 0.07031264,
#        0.08751188, 0.09876917, 0.10408456, 0.11073383, 0.0792053 ,
#        0.05818628, 0.08041794, 0.07880109, 0.09100827, 0.09699062,
#        0.08963399, 0.06831181, 0.09982011, 0.1198286 , 0.08959353,
#        0.08613755, 0.10299316, 0.12197094, 0.12892336, 0.13199536,
#        0.13904889, 0.17629698, 0.16475676, 0.17015298, 0.15665229,
#        0.15250912, 0.15368134, 0.16287716, 0.16338243, 0.1696073 ,
#        0.15564176, 0.14517266, 0.14796173, 0.16045189, 0.17205275,
#        0.17587259, 0.18399724, 0.16934455, 0.175913  , 0.18805958,
#        0.18446209, 0.19202083, 0.21584915, 0.20774468, 0.21855735,
#        0.21595021, 0.22476204, 0.22401421, 0.22937002, 0.22464076,
#        0.20410678, 0.20004443, 0.21219101, 0.21039229, 0.20984657,
#        0.21259523, 0.20740111, 0.20370257, 0.21243353, 0.20339941,
#        0.20772445, 0.23656501, 0.22999657, 0.23179529, 0.23927321,
#        0.2644354 , 0.28252388, 0.2934982 , 0.28357488, 0.27688515,
#        0.27080174, 0.28454494, 0.26635541, 0.27286326, 0.28862752,
#        0.27648094, 0.2767841 , 0.28096763, 0.27411626, 0.26554699,
#        0.25022739, 0.26574909, 0.286566  , 0.2991168 , 0.30970713,
#        0.30372478, 0.29291211, 0.29062835, 0.30192606, 0.30691811,
#        0.31566926, 0.31124316, 0.31106128, 0.29931891, 0.30091553,
#        0.29388228, 0.29596393, 0.30002628, 0.30172395, 0.29669153,
#        0.29709574, 0.29262918, 0.29406415, 0.28715209, 0.29737867,
#        0.2946907 , 0.29182076, 0.2971968 , 0.29733821, 0.30798923,
#        0.30594794, 0.31419393, 0.33185797, 0.32900825, 0.33074638,
#        0.33311096, 0.3540088 , 0.38745733, 0.3925908 , 0.38179837,
#        0.37605848, 0.38242482, 0.38478949, 0.36498311, 0.32197501,
#        0.34198349, 0.347602  , 0.371976  , 0.38559792, 0.39865398,
#        0.44342045, 0.46243864, 0.48382141, 0.52302996, 0.51494572,
#        0.52333312, 0.52796133, 0.51799754, 0.49352249, 0.49526063,
#        0.48527661, 0.48986436, 0.46767316, 0.4575881 , 0.47052288,
#        0.47068452, 0.45192913, 0.44461286, 0.44228864, 0.4509186 ,
#        0.44220781, 0.44261203, 0.4462297 , 0.46926978, 0.47505003,
#        0.48062817, 0.45768915, 0.45973034, 0.46714767, 0.45673921,
#        0.46646053, 0.46241841, 0.4450373 , 0.45465756, 0.45332364,
#        0.46846136, 0.48462983, 0.47783905, 0.47452454, 0.47009843,
#        0.45207054, 0.48359907, 0.48293216, 0.48220456, 0.48509464,
#        0.49572543, 0.52026107, 0.51504678, 0.50870067, 0.50534569,
#        0.50484043, 0.50704336, 0.52505102, 0.54170453, 0.51696678,
#        0.53056848, 0.54948561, 0.55666037, 0.56425958, 0.57153539,
#        0.56425958, 0.5412195 , 0.5549627 , 0.58000361, 0.61987917,
#        0.618909  , 0.6039734 , 0.62812506, 0.66310962, 0.66450413,
#        0.65490409, 0.65253941, 0.68875684, 0.67962161, 0.6976495 ,
#        0.71183738, 0.70981632, 0.70165116, 0.71650595, 0.69562844,
#        0.67816651, 0.64429353, 0.62169813, 0.66450413, 0.66961737,
#        0.67501364, 0.65601568, 0.66658578, 0.67016309, 0.66745489,
#        0.67867177, 0.67743891, 0.65704644, 0.64429353, 0.62228421,
#        0.61640291, 0.61040032, 0.58089286, 0.59093756, 0.57200019,
#        0.59111944, 0.55536691, 0.56417875, 0.58285332, 0.60261925,
#        0.61035996, 0.60249806, 0.60225549, 0.60067911, 0.62812506,
#        0.62058654, 0.62044503, 0.62812506, 0.63835164, 0.59863782,
#        0.6058934 , 0.61141085, 0.65352981, 0.64880045, 0.62408294,
#        0.62127368, 0.62848881, 0.65722831, 0.66248307, 0.66490834,
#        0.69684108, 0.69878131, 0.71141294, 0.72836961, 0.6900503 ,
#        0.63340004, 0.63922065, 0.67768147, 0.65848141, 0.65494455,
#        0.64641564, 0.64067585, 0.63946322, 0.64550617, 0.64914407,
#        0.6465167 , 0.61195658, 0.60548919, 0.61801976, 0.62505301,
#        0.63378402, 0.64906325, 0.65439883, 0.64071622, 0.63240974,
#        0.62004082, 0.61842397, 0.63540087, 0.630995  , 0.62493182,
#        0.62614446, 0.6329756 , 0.63705818, 0.64582956, 0.66927385,
#        0.65870365, 0.65585403, 0.65722831, 0.65035671, 0.65344889,
#        0.65439883, 0.65787509, 0.67954079, 0.67913658, 0.68188524,
#        0.68916105, 0.71315107, 0.70555186, 0.70613795, 0.70896743,
#        0.71503061, 0.70561246, 0.71907273, 0.70751223, 0.71644536,
#        0.74534651, 0.7384749 , 0.73584753, 0.74069807, 0.73821221,
#        0.72319567, 0.72594433, 0.70739105, 0.70152998, 0.69760904,
#        0.68511893, 0.68000569, 0.67460942, 0.67865154, 0.68228945,
#        0.68148103, 0.67501364, 0.66698999, 0.6806726 , 0.68740269,
#        0.68101622, 0.66901105, 0.65738996, 0.68079389, 0.66949618,
#        0.67137573, 0.69237452, 0.70945247, 0.70997796, 0.71098849,
#        0.72917803, 0.73144166, 0.73609009, 0.73564542, 0.74837809,
#        0.78031083, 0.79102245, 0.82077248, 0.80597829, 0.83099897,
#        0.84413585, 0.84924919, 0.86576119, 0.86705475, 0.88180848,
#        0.88821518, 0.88965015, 0.89571333, 0.92908104, 0.93290083,
#        0.93057661, 0.90945654, 0.91309444, 0.91390287, 0.93734716,
#        0.95391984, 0.96446981, 0.92926292, 0.93041496, 0.93599301,
#        0.94844275, 0.94138928, 0.94947351, 0.92841403, 0.90753653,
#        0.89577392, 0.90707172, 0.89692597, 0.88983203, 0.90363592,
#        0.9252208 , 0.93534633, 0.96766305, 0.87065219, 0.8587684 ,
#        0.86458901, 0.849714  , 0.84698557, 0.8565856 , 0.8376281 ,
#        0.81052567, 0.79991511, 0.7857677 , 0.79587299, 0.79910669,
#        0.77162028, 0.7598779 , 0.77079162, 0.79375088, 0.79225532,
#        0.80799935, 0.79837909, 0.80436144, 0.79797487, 0.78010873,
#        0.80019804, 0.81729622, 0.82295519, 0.80856521, 0.78641447,
#        0.78184686, 0.76870997, 0.77525819, 0.77932054, 0.77036718,
#        0.76816425, 0.80234038, 0.82012571, 0.83593043, 0.85886946,
#        0.81487095, 0.81580066, 0.84680369, 0.83265628, 0.83633464,
#        0.84708662, 0.83698132, 0.82948317, 0.83427312, 0.83576869,
#        0.810081  , 0.83281792, 0.8489258 , 0.85852584, 0.86450819,
#        0.86786317, 0.88433481, 0.88075749, 0.87873643, 0.89947252,
#        0.9050102 , 0.93197112, 0.93225405, 0.91592393, 0.92578666,
#        0.95189878, 0.94987772, 0.94201582, 0.95028194, 0.9515148 ,
#        0.99284547, 1.        , 0.97190727, 0.93168819, 0.91556017,
#        0.90302961, 0.89579415, 0.85654524, 0.86499323, 0.89547076,
#        0.90153394, 0.92750456, 0.93372948, 0.91471129, 0.90951713,
#        0.89530912, 0.90545488, 0.91026496, 0.88277855, 0.89086279,
#        0.90622284, 0.92966713, 0.91875341, 0.91010331, 0.88906406,
#        0.83427312, 0.82847264, 0.76195965, 0.79061824, 0.78815251,
#        0.80840356, 0.81814511, 0.80074377, 0.77831001, 0.78980981,
#        0.84520707, 0.85246266, 0.8435094 , 0.83831524, 0.84049795,
#        0.85296792, 0.87077348, 0.85246266, 0.85650478, 0.88277855,
#        0.88479961, 0.87550274, 0.87113723, 0.88318276, 0.88932676,
#        0.89498573, 0.89815883, 0.90181697, 0.91592393, 0.89941183,
#        0.87833222, 0.86357849, 0.86907581, 0.86594316, 0.86885347,
#        0.81507306, 0.78138196, 0.79789405, 0.83322213, 0.83487944,
#        0.81935774, 0.8133147 , 0.80852484, 0.82135857, 0.82087354,
#        0.80304775, 0.79195216, 0.80005663, 0.77546029, 0.74407328,
#        0.77444976, 0.75834188, 0.74538697, 0.75834188, 0.75205646,
#        0.74550815, 0.78295844, 0.69684108, 0.71302978, 0.71179692,
#        0.71527318, 0.6661412 , 0.67685282, 0.69651769, 0.71961846,
#        0.73524121, 0.74132462, 0.74385094, 0.77816849, 0.75632082,
#        0.74777178, 0.74393176, 0.7465996 , 0.74615493, 0.6816629 ,
#        0.67448814, 0.68511893, 0.65765275, 0.61351284, 0.63176296,
#        0.65456047, 0.67784312, 0.69399136, 0.71604114, 0.72776329,
#        0.71406054, 0.71341377, 0.70694638, 0.70575397, 0.69484025,
#        0.68752397, 0.6856242 , 0.71100872, 0.70492532, 0.6467188 ,
#        0.63631035, 0.61801976, 0.59053335, 0.58487438, 0.60965259,
#        0.61601893, 0.64350534, 0.66209909, 0.66187675, 0.66414038,
#        0.64287879, 0.64833565, 0.68538163, 0.71503061, 0.71341377,
#        0.71367646, 0.71585927, 0.72810691, 0.74736757, 0.73968754,
#        0.73928333, 0.75547203, 0.75797813, 0.76050445, 0.75387542,
#        0.75019705, 0.75393601, 0.74429552, 0.71300955, 0.70500614,
#        0.69067685, 0.6915055 , 0.63661351, 0.66131089, 0.65278198,
#        0.65249905, 0.64924513, 0.64686032, 0.64510196, 0.66858671,
#        0.67198205, 0.69482002, 0.69482002, 0.64987168, 0.64429353,
#        0.60387234, 0.59894098, 0.6159987 , 0.60312451, 0.59550518,
#        0.59538389, 0.57400112, 0.59417126, 0.5957881 , 0.59983022,
#        0.58370221, 0.59336283, 0.61316922, 0.64124171, 0.62735709,
#        0.6058934 , 0.62543709, 0.62895371, 0.62503287, 0.63257139,
#        0.63275326, 0.6558338 , 0.64914407, 0.64631459, 0.65520725,
#        0.66652519, 0.66496893, 0.65817825, 0.66248307, 0.67574124,
#        0.68610923, 0.69362761, 0.68269366, 0.67103211, 0.68273412,
#        0.68538163, 0.67258836, 0.70696661, 0.72877382, 0.72190222,
#        0.73380624, 0.73231067, 0.73362436, 0.71422219, 0.70704743,
#        0.721498  , 0.72849089, 0.74453808, 0.75163202, 0.7586855 ,
#        0.7554518 , 0.77364134, 0.77081186, 0.76838658, 0.75262232,
#        0.74696335, 0.74108205, 0.71557634, 0.69930681, 0.71212031,
#        0.74166814, 0.72471147, 0.69490084, 0.68249156, 0.67002158,
#        0.7008832 , 0.70294472, 0.69158632, 0.69484025, 0.6974474 ,
#        0.69522423, 0.69603265, 0.70338929])

# %%
y_pred
# Out:
# array([[0.19431266],
#        [0.20135766],
#        [0.20774908],
#        [0.2127479 ],
#        [0.21589859],
#        [0.2172637 ],
#        [0.21693774],
#        [0.21464044],
#        [0.20998058],
#        [0.20308687],
#        [0.1946833 ],
#        [0.18614954],
#        [0.1790775 ],
#        [0.17505181],
#        [0.1757017 ],
#        [0.17966622],
#        [0.18526876],
#        [0.19109574],
#        [0.1961341 ],
#        [0.20011505],
#        [0.20330559],
#        [0.20575112],
#        [0.20746794],
#        [0.20793094],
#        [0.20707679],
#        [0.20544323],
#        [0.20411311],
#        [0.20341575],
#        [0.20345521],
#        [0.203735  ],
#        [0.20375577],
#        [0.20294094],
#        [0.20117253],
#        [0.19904283],
#        [0.19807845],
#        [0.19944498],
#        [0.2035968 ],
#        [0.20878108],
#        [0.21331173],
#        [0.21662657],
#        [0.21917787],
#        [0.22083154],
#        [0.22126378],
#        [0.22038372],
#        [0.21891849],
#        [0.21890225],
#        [0.22193867],
#        [0.22917588],
#        [0.24000882],
#        [0.2520309 ],
#        [0.26309386],
#        [0.27242547],
#        [0.28080153],
#        [0.287404  ],
#        [0.2905192 ],
#        [0.28990063],
#        [0.28649056],
#        [0.2811193 ],
#        [0.27457702],
#        [0.26754293],
#        [0.26058108],
#        [0.25337154],
#        [0.24629533],
#        [0.23988362],
#        [0.23464759],
#        [0.23037368],
#        [0.22754823],
#        [0.22608295],
#        [0.22516601],
#        [0.22406118],
#        [0.22261707],
#        [0.22106287],
#        [0.22021586],
#        [0.22161809],
#        [0.22697099],
#        [0.23804358],
#        [0.25251547],
#        [0.26539233],
#        [0.2741392 ],
#        [0.27996746],
#        [0.28482705],
#        [0.28924015],
#        [0.2936496 ],
#        [0.29753184],
#        [0.30058813],
#        [0.30242372],
#        [0.30345446],
#        [0.30347094],
#        [0.30332372],
#        [0.303747  ],
#        [0.30488202],
#        [0.3065284 ],
#        [0.3080381 ],
#        [0.30867124],
#        [0.30824253],
#        [0.307284  ],
#        [0.3066725 ],
#        [0.30677354],
#        [0.30561954],
#        [0.3022607 ],
#        [0.29663286],
#        [0.28878638],
#        [0.27911106],
#        [0.2684181 ],
#        [0.25782195],
#        [0.24863094],
#        [0.24167232],
#        [0.23655283],
#        [0.23266894],
#        [0.22971788],
#        [0.2282766 ],
#        [0.22803831],
#        [0.22876424],
#        [0.23021865],
#        [0.23225212],
#        [0.23508029],
#        [0.23965038],
#        [0.24724704],
#        [0.25659385],
#        [0.2663994 ],
#        [0.27577314],
#        [0.28368777],
#        [0.28963616],
#        [0.2941973 ],
#        [0.29645032],
#        [0.29663458],
#        [0.29466665],
#        [0.29103005],
#        [0.28648493],
#        [0.28229097],
#        [0.27951804],
#        [0.28033355],
#        [0.28475982],
#        [0.29122022],
#        [0.2972157 ],
#        [0.3014294 ],
#        [0.30356288],
#        [0.30455613],
#        [0.3049807 ],
#        [0.30462658],
#        [0.3035105 ],
#        [0.3016349 ],
#        [0.29834425],
#        [0.293366  ],
#        [0.2866663 ],
#        [0.27883577],
#        [0.270372  ],
#        [0.26196063],
#        [0.25392452],
#        [0.24630016],
#        [0.23890477],
#        [0.23168984],
#        [0.22538696],
#        [0.22091705],
#        [0.21858387],
#        [0.2183196 ],
#        [0.2191336 ],
#        [0.22026679],
#        [0.22143185],
#        [0.22217807],
#        [0.22201331],
#        [0.2206167 ],
#        [0.21742618],
#        [0.2127099 ],
#        [0.20804203],
#        [0.20495158],
#        [0.20371886],
#        [0.20448732],
#        [0.20703007],
#        [0.21128263],
#        [0.216521  ],
#        [0.22218084],
#        [0.22877668],
#        [0.23685203],
#        [0.2475373 ],
#        [0.2609051 ],
#        [0.2734221 ],
#        [0.28244495],
#        [0.28733525],
#        [0.2893749 ],
#        [0.2895812 ],
#        [0.2876251 ],
#        [0.2831327 ],
#        [0.27661282],
#        [0.26925108],
#        [0.2629149 ],
#        [0.25918236],
#        [0.25662076],
#        [0.25361726],
#        [0.25001663],
#        [0.24535695],
#        [0.24010327],
#        [0.23456879],
#        [0.2292362 ],
#        [0.22468445],
#        [0.22122912],
#        [0.21848331],
#        [0.21603803],
#        [0.21448025],
#        [0.21461132],
#        [0.21762389],
#        [0.22182974],
#        [0.22468951],
#        [0.22544989],
#        [0.2239091 ],
#        [0.2207243 ],
#        [0.21804251],
#        [0.21820009],
#        [0.2233639 ],
#        [0.2340426 ],
#        [0.24979478],
#        [0.26597926],
#        [0.278899  ],
#        [0.28708413],
#        [0.29107887],
#        [0.29224032],
#        [0.2913957 ],
#        [0.28883427],
#        [0.28490016],
#        [0.2804502 ],
#        [0.2771808 ],
#        [0.2766717 ],
#        [0.27958953],
#        [0.28488293],
#        [0.29068586],
#        [0.29490092],
#        [0.29726943],
#        [0.29829407],
#        [0.29894644],
#        [0.29966706],
#        [0.29934084],
#        [0.29749176],
#        [0.29470748],
#        [0.29216477],
#        [0.29016834],
#        [0.2886249 ],
#        [0.28698552],
#        [0.2849803 ],
#        [0.28186998],
#        [0.27679455],
#        [0.26993626],
#        [0.26187506],
#        [0.25361896],
#        [0.24642366],
#        [0.24157822],
#        [0.23945636],
#        [0.24050845],
#        [0.2449743 ],
#        [0.2527555 ],
#        [0.26184273],
#        [0.2706772 ],
#        [0.2782364 ],
#        [0.28395468],
#        [0.28703582],
#        [0.28664267],
#        [0.28320724],
#        [0.27741036],
#        [0.26966414],
#        [0.25998604],
#        [0.24885145],
#        [0.23761478],
#        [0.2274192 ],
#        [0.21999928],
#        [0.21653889],
#        [0.21466827],
#        [0.21239614],
#        [0.20772266],
#        [0.19846383],
#        [0.185883  ],
#        [0.17136493],
#        [0.15602855],
#        [0.14058016],
#        [0.12624076],
#        [0.11391227],
#        [0.10416625],
#        [0.09776786],
#        [0.0959641 ],
#        [0.0973465 ],
#        [0.10080348],
#        [0.10533214],
#        [0.10906639],
#        [0.1108098 ],
#        [0.11068423],
#        [0.10924047],
#        [0.10745387],
#        [0.10615523],
#        [0.10547717],
#        [0.10476169],
#        [0.10458376],
#        [0.10578704],
#        [0.10747817],
#        [0.10882016],
#        [0.10993052],
#        [0.11154802],
#        [0.11410253],
#        [0.1175662 ],
#        [0.12173183],
#        [0.12734479],
#        [0.13392502],
#        [0.14080428],
#        [0.14679918],
#        [0.15123838],
#        [0.154047  ],
#        [0.15569185],
#        [0.15679577],
#        [0.15803853],
#        [0.15931374],
#        [0.16020308],
#        [0.16033947],
#        [0.16043144],
#        [0.16159038],
#        [0.16396403],
#        [0.16751121],
#        [0.17128296],
#        [0.17467576],
#        [0.17786086],
#        [0.18080974],
#        [0.18375151],
#        [0.18772471],
#        [0.19262184],
#        [0.19846013],
#        [0.20442528],
#        [0.21016812],
#        [0.21519394],
#        [0.21950623],
#        [0.2226881 ],
#        [0.22399037],
#        [0.22315393],
#        [0.22084665],
#        [0.21786147],
#        [0.21488266],
#        [0.21262582],
#        [0.21123204],
#        [0.210449  ],
#        [0.21048224],
#        [0.21089694],
#        [0.21153362],
#        [0.21380281],
#        [0.21796685],
#        [0.2233511 ],
#        [0.22959313],
#        [0.23875304],
#        [0.25154263],
#        [0.26633438],
#        [0.27926135],
#        [0.28782266],
#        [0.29192325],
#        [0.29336354],
#        [0.2930194 ],
#        [0.2915773 ],
#        [0.29073486],
#        [0.29070407],
#        [0.29134685],
#        [0.2927764 ],
#        [0.2943368 ],
#        [0.29485327],
#        [0.29301918],
#        [0.28978515],
#        [0.28820416],
#        [0.2904656 ],
#        [0.29700613],
#        [0.30475417],
#        [0.31009895],
#        [0.31187907],
#        [0.31166735],
#        [0.31103832],
#        [0.31129792],
#        [0.31235138],
#        [0.31369132],
#        [0.31415936],
#        [0.31385338],
#        [0.3129223 ],
#        [0.3117663 ],
#        [0.31106517],
#        [0.3112288 ],
#        [0.31192422],
#        [0.31281793],
#        [0.313421  ],
#        [0.31369743],
#        [0.31339073],
#        [0.3131678 ],
#        [0.31320313],
#        [0.3132836 ],
#        [0.31357956],
#        [0.314111  ],
#        [0.3154393 ],
#        [0.31721336],
#        [0.31943733],
#        [0.3231095 ],
#        [0.32738668],
#        [0.3311143 ],
#        [0.3337177 ],
#        [0.3369148 ],
#        [0.34442234],
#        [0.35584185],
#        [0.36610836],
#        [0.37203485],
#        [0.37453878],
#        [0.37515604],
#        [0.37375104],
#        [0.37038893],
#        [0.36594886],
#        [0.3613309 ],
#        [0.35808545],
#        [0.35990435],
#        [0.36820045],
#        [0.3830781 ],
#        [0.4023919 ],
#        [0.42455724],
#        [0.44892633],
#        [0.4717461 ],
#        [0.49050206],
#        [0.5040262 ],
#        [0.5102477 ],
#        [0.50626224],
#        [0.49658996],
#        [0.48542684],
#        [0.47663337],
#        [0.46905446],
#        [0.462147  ],
#        [0.45845792],
#        [0.45868266],
#        [0.45883697],
#        [0.4570526 ],
#        [0.45373154],
#        [0.45144922],
#        [0.44963336],
#        [0.44818428],
#        [0.44766504],
#        [0.45134902],
#        [0.45862827],
#        [0.46754855],
#        [0.4720049 ],
#        [0.4712541 ],
#        [0.46864837],
#        [0.4645676 ],
#        [0.46176276],
#        [0.46028453],
#        [0.45723492],
#        [0.4543854 ],
#        [0.4525988 ],
#        [0.4543327 ],
#        [0.4607613 ],
#        [0.46850848],
#        [0.47430348],
#        [0.47624934],
#        [0.47230428],
#        [0.46994376],
#        [0.4708372 ],
#        [0.47363502],
#        [0.47711635],
#        [0.4817536 ],
#        [0.48952138],
#        [0.49831748],
#        [0.50459635],
#        [0.50666654],
#        [0.50516003],
#        [0.5024425 ],
#        [0.5031303 ],
#        [0.5087313 ],
#        [0.5134057 ],
#        [0.5171363 ],
#        [0.5227305 ],
#        [0.53053856],
#        [0.53960484],
#        [0.548679  ],
#        [0.5544253 ],
#        [0.5521069 ],
#        [0.5466488 ],
#        [0.54585606],
#        [0.55396837],
#        [0.5680867 ],
#        [0.5808224 ],
#        [0.5929708 ],
#        [0.608084  ],
#        [0.6240685 ],
#        [0.6352937 ],
#        [0.6396924 ],
#        [0.6462983 ],
#        [0.6530458 ],
#        [0.661885  ],
#        [0.67343277],
#        [0.6836282 ],
#        [0.6877991 ],
#        [0.6907248 ],
#        [0.6880217 ],
#        [0.6785163 ],
#        [0.6643758 ],
#        [0.6471103 ],
#        [0.633373  ],
#        [0.6303047 ],
#        [0.6375072 ],
#        [0.6460105 ],
#        [0.6541125 ],
#        [0.6610001 ],
#        [0.6649443 ],
#        [0.66831034],
#        [0.67045385],
#        [0.6663488 ],
#        [0.65565366],
#        [0.6412968 ],
#        [0.6262067 ],
#        [0.6123215 ],
#        [0.5988044 ],
#        [0.58786255],
#        [0.57947177],
#        [0.57710046],
#        [0.5734096 ],
#        [0.5695999 ],
#        [0.5699115 ],
#        [0.5753727 ],
#        [0.5845471 ],
#        [0.59305906],
#        [0.59831125],
#        [0.59947085],
#        [0.60257345],
#        [0.606226  ],
#        [0.6087493 ],
#        [0.61109096],
#        [0.6150898 ],
#        [0.61121017],
#        [0.6028101 ],
#        [0.5958681 ],
#        [0.59861827],
#        [0.6082569 ],
#        [0.6152945 ],
#        [0.61692494],
#        [0.6163585 ],
#        [0.6203412 ],
#        [0.62892485],
#        [0.6393023 ],
#        [0.6531293 ],
#        [0.6676471 ],
#        [0.68172085],
#        [0.69574594],
#        [0.69676054],
#        [0.67972976],
#        [0.6587485 ],
#        [0.64205384],
#        [0.6338952 ],
#        [0.63366216],
#        [0.63588   ],
#        [0.63705516],
#        [0.63674676],
#        [0.6370094 ],
#        [0.63878614],
#        [0.6406217 ],
#        [0.63402265],
#        [0.621806  ],
#        [0.61133075],
#        [0.6074568 ],
#        [0.61032164],
#        [0.6186131 ],
#        [0.62958205],
#        [0.6370259 ],
#        [0.6376447 ],
#        [0.63077885],
#        [0.6205305 ],
#        [0.6151835 ],
#        [0.61414593],
#        [0.61445   ],
#        [0.615161  ],
#        [0.61729467],
#        [0.6209802 ],
#        [0.62661296],
#        [0.6359837 ],
#        [0.64447093],
#        [0.6488271 ],
#        [0.64944386],
#        [0.64630824],
#        [0.642365  ],
#        [0.63960546],
#        [0.639343  ],
#        [0.6449334 ],
#        [0.65392923],
#        [0.6631616 ],
#        [0.6715233 ],
#        [0.6819955 ],
#        [0.69044197],
#        [0.6948708 ],
#        [0.69622225],
#        [0.69712263],
#        [0.6956256 ],
#        [0.69627005],
#        [0.69600886],
#        [0.6972592 ],
#        [0.70537376],
#        [0.7155179 ],
#        [0.7229498 ],
#        [0.72753567],
#        [0.7287156 ],
#        [0.72388136],
#        [0.71764654],
#        [0.70895475],
#        [0.7000374 ],
#        [0.69252616],
#        [0.6859293 ],
#        [0.68055356],
#        [0.67634106],
#        [0.6750274 ],
#        [0.6768629 ],
#        [0.67992955],
#        [0.6810843 ],
#        [0.67834026],
#        [0.67653275],
#        [0.6778236 ],
#        [0.67924696],
#        [0.6768668 ],
#        [0.66936016],
#        [0.6659228 ],
#        [0.66444516],
#        [0.6644156 ],
#        [0.66922355],
#        [0.6792395 ],
#        [0.6908093 ],
#        [0.70008236],
#        [0.7092025 ],
#        [0.7166845 ],
#        [0.72188085],
#        [0.723827  ],
#        [0.7263974 ],
#        [0.7358946 ],
#        [0.7501687 ],
#        [0.76893204],
#        [0.7814772 ],
#        [0.79267746],
#        [0.80356264],
#        [0.81197405],
#        [0.82053345],
#        [0.8260901 ],
#        [0.8322075 ],
#        [0.8382183 ],
#        [0.8421942 ],
#        [0.84557074],
#        [0.8578283 ],
#        [0.87110054],
#        [0.87806815],
#        [0.8751051 ],
#        [0.8711422 ],
#        [0.86698467],
#        [0.86749095],
#        [0.87890524],
#        [0.895214  ],
#        [0.8954136 ],
#        [0.8928552 ],
#        [0.8888049 ],
#        [0.8871174 ],
#        [0.8872698 ],
#        [0.88974684],
#        [0.89008516],
#        [0.8859393 ],
#        [0.8780151 ],
#        [0.8703528 ],
#        [0.8645758 ],
#        [0.8608802 ],
#        [0.8617185 ],
#        [0.87122065],
#        [0.88506246],
#        [0.9020759 ],
#        [0.8921319 ],
#        [0.8767456 ],
#        [0.85805273],
#        [0.840271  ],
#        [0.82680994],
#        [0.8203234 ],
#        [0.8198758 ],
#        [0.81686044],
#        [0.8110196 ],
#        [0.8019316 ],
#        [0.79338217],
#        [0.7884547 ],
#        [0.783306  ],
#        [0.7762066 ],
#        [0.7702102 ],
#        [0.7723158 ],
#        [0.7798826 ],
#        [0.790538  ],
#        [0.7967093 ],
#        [0.7989017 ],
#        [0.79589206],
#        [0.7868962 ],
#        [0.78101045],
#        [0.78406286],
#        [0.79360485],
#        [0.7987974 ],
#        [0.79340845],
#        [0.7848961 ],
#        [0.77451456],
#        [0.7655268 ],
#        [0.76136535],
#        [0.7613633 ],
#        [0.7625837 ],
#        [0.771109  ],
#        [0.7852681 ],
#        [0.80185443],
#        [0.81953055],
#        [0.81923383],
#        [0.8097989 ],
#        [0.80695903],
#        [0.8056974 ],
#        [0.8063608 ],
#        [0.81106216],
#        [0.81374514],
#        [0.81265295],
#        [0.8113391 ],
#        [0.811131  ],
#        [0.8067104 ],
#        [0.8048461 ],
#        [0.81097233],
#        [0.8229106 ],
#        [0.83471185],
#        [0.8425641 ],
#        [0.84963876],
#        [0.851698  ],
#        [0.8494113 ],
#        [0.85100657],
#        [0.85568595],
#        [0.8679841 ],
#        [0.87890446],
#        [0.8790806 ],
#        [0.8779942 ],
#        [0.8821556 ],
#        [0.88776815],
#        [0.8899015 ],
#        [0.89160305],
#        [0.89317507],
#        [0.9028668 ],
#        [0.91753906],
#        [0.9187663 ],
#        [0.9132771 ],
#        [0.90061873],
#        [0.88441074],
#        [0.86884075],
#        [0.85373783],
#        [0.8421703 ],
#        [0.8384581 ],
#        [0.8483425 ],
#        [0.8680175 ],
#        [0.88605213],
#        [0.8897819 ],
#        [0.8842847 ],
#        [0.87675065],
#        [0.8690567 ],
#        [0.8640772 ],
#        [0.8591589 ],
#        [0.8556118 ],
#        [0.8572519 ],
#        [0.8690112 ],
#        [0.8791462 ],
#        [0.8805928 ],
#        [0.87569505],
#        [0.8628058 ],
#        [0.8444687 ],
#        [0.8205376 ],
#        [0.7967891 ],
#        [0.7787281 ],
#        [0.77051574],
#        [0.7785472 ],
#        [0.79031813],
#        [0.79262   ],
#        [0.79110044],
#        [0.79958326],
#        [0.8139034 ],
#        [0.82412356],
#        [0.825869  ],
#        [0.8227963 ],
#        [0.8214972 ],
#        [0.8269462 ],
#        [0.8282657 ],
#        [0.8279252 ],
#        [0.83433247],
#        [0.8432474 ],
#        [0.8466378 ],
#        [0.8450766 ],
#        [0.8446979 ],
#        [0.84680337],
#        [0.85127604],
#        [0.8563147 ],
#        [0.8606438 ],
#        [0.8669442 ],
#        [0.86735576],
#        [0.8627878 ],
#        [0.854375  ],
#        [0.8452341 ],
#        [0.8378169 ],
#        [0.8344532 ],
#        [0.8284177 ],
#        [0.816076  ],
#        [0.80225986],
#        [0.7943347 ],
#        [0.7985715 ],
#        [0.806737  ],
#        [0.81090325],
#        [0.8094271 ],
#        [0.80844146],
#        [0.807965  ],
#        [0.80328476],
#        [0.79594904],
#        [0.7891616 ],
#        [0.78151923],
#        [0.7704516 ],
#        [0.7614469 ],
#        [0.75581837],
#        [0.75170976],
#        [0.7516842 ],
#        [0.7531416 ],
#        [0.75275105],
#        [0.7586748 ],
#        [0.7482297 ],
#        [0.73453206],
#        [0.7208876 ],
#        [0.71128386],
#        [0.6999589 ],
#        [0.6889355 ],
#        [0.68479633],
#        [0.6905191 ],
#        [0.7035061 ],
#        [0.7187489 ],
#        [0.73201454],
#        [0.74663657],
#        [0.7538021 ],
#        [0.75106883],
#        [0.742497  ],
#        [0.7340713 ],
#        [0.7286869 ],
#        [0.7164058 ],
#        [0.7005302 ],
#        [0.6851834 ],
#        [0.67102635],
#        [0.6554605 ],
#        [0.64094627],
#        [0.63383526],
#        [0.63866913],
#        [0.6522382 ],
#        [0.6711829 ],
#        [0.6913718 ],
#        [0.7051849 ],
#        [0.71091425],
#        [0.7087703 ],
#        [0.70240474],
#        [0.6930594 ],
#        [0.6828561 ],
#        [0.6748767 ],
#        [0.67601085],
#        [0.6827099 ],
#        [0.67699796],
#        [0.6644342 ],
#        [0.6482659 ],
#        [0.6296108 ],
#        [0.610816  ],
#        [0.59669226],
#        [0.5926926 ],
#        [0.59975684],
#        [0.61455727],
#        [0.63146377],
#        [0.646302  ],
#        [0.6517284 ],
#        [0.6502357 ],
#        [0.6525448 ],
#        [0.6629758 ],
#        [0.6771998 ],
#        [0.6897605 ],
#        [0.6980748 ],
#        [0.7046003 ],
#        [0.7134281 ],
#        [0.7198088 ],
#        [0.72217673],
#        [0.7258158 ],
#        [0.7305911 ],
#        [0.7354123 ],
#        [0.7371717 ],
#        [0.73578024],
#        [0.7344766 ],
#        [0.7319363 ],
#        [0.7234136 ],
#        [0.7126907 ],
#        [0.7007921 ],
#        [0.69013685],
#        [0.6769421 ],
#        [0.66443413],
#        [0.6552202 ],
#        [0.65188104],
#        [0.6522327 ],
#        [0.6531905 ],
#        [0.65314895],
#        [0.6562873 ],
#        [0.662133  ],
#        [0.67160916],
#        [0.6815979 ],
#        [0.6782318 ],
#        [0.6648203 ],
#        [0.64641   ],
#        [0.6260337 ],
#        [0.60847   ],
#        [0.5961893 ],
#        [0.59018743],
#        [0.58903754],
#        [0.58629686],
#        [0.58580947],
#        [0.5877342 ],
#        [0.5912569 ],
#        [0.59157497],
#        [0.5903215 ],
#        [0.59208757],
#        [0.5999614 ],
#        [0.60913527],
#        [0.6115483 ],
#        [0.61170375],
#        [0.6122786 ],
#        [0.6126169 ],
#        [0.6140053 ],
#        [0.61601084],
#        [0.62201756],
#        [0.62900764],
#        [0.6337354 ],
#        [0.6374136 ],
#        [0.64249206],
#        [0.6473699 ],
#        [0.64908904],
#        [0.64902335],
#        [0.6512724 ],
#        [0.6575013 ],
#        [0.66661286],
#        [0.6725513 ],
#        [0.6714827 ],
#        [0.66898763],
#        [0.66798246],
#        [0.66577286],
#        [0.6699545 ],
#        [0.68190306],
#        [0.6956511 ],
#        [0.7089786 ],
#        [0.71822464],
#        [0.72251815],
#        [0.7177653 ],
#        [0.70747024],
#        [0.7006272 ],
#        [0.700812  ],
#        [0.70887595],
#        [0.7213945 ],
#        [0.73476774],
#        [0.7439255 ],
#        [0.7521657 ],
#        [0.7570204 ],
#        [0.7573597 ],
#        [0.7508349 ],
#        [0.7416877 ],
#        [0.732861  ],
#        [0.7227773 ],
#        [0.71130925],
#        [0.7019608 ],
#        [0.7031683 ],
#        [0.71069986],
#        [0.7117786 ],
#        [0.7045502 ],
#        [0.69308054],
#        [0.68692875],
#        [0.68848413],
#        [0.69167876],
#        [0.6945331 ],
#        [0.6966563 ],
#        [0.6970627 ],
#        [0.6961666 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00033267])

# %%
scale_factor = 1 / 0.00041967  # Replace with your scale factor
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# %%
# scale_factor = 1/0.00041967
# y_pred = y_pred_inverse * scale_factor
# y_test = y_test * scale_factor

# %%
# y_pred = np.squeeze(y_pred)
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Calculation of mean absolute error

# %%
from sklearn.metrics import mean_absolute_error

y_pred = y_pred.flatten()
mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 1.47%

# %% [markdown]
# Calculation of R2 score

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9839705981615191

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
