# %% [markdown]
# <a href="https://colab.research.google.com/github/smitike/Stock-Price-Prediction-Using-LSTM/blob/main/(2.36%25)lstm_improved_model_diff_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
import yfinance as yf
import pandas as pd

# Define start and end date
START = "2010-01-01"
TODAY = "2023-01-01"

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  292.332886  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  292.410706  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  285.799042  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  277.845703  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  272.167297  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %% [markdown]
# # Define start day to fetch the dataset from the yahoo finance library
#
# ---

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  292.332886  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  292.410706  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  285.799042  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  277.845703  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  272.167297  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-4-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %% [markdown]
# Visualizing Closing Price

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3204    3252.899902  3272.000000  3225.050049  3228.350098   870157
# 3205    3259.500000  3273.800049  3231.500000  3269.199951   835883
# 3206    3257.100098  3266.100098  3226.000000  3249.800049   910795
# 3207    3268.750000  3271.500000  3228.000000  3231.100098  1037927
# 3208    3256.699951  3299.000000  3246.199951  3286.050049  1163131
#
# [3209 rows x 5 columns]

# %% [markdown]
# # Plotting moving averages of 100 day
#
# ---

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3227.688494
# 3205    3227.295493
# 3206    3226.948494
# 3207    3226.240994
# 3208    3225.258494
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %% [markdown]
# # Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
#
# ---

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3320.515244
# 3205    3318.812994
# 3206    3316.935494
# 3207    3315.174495
# 3208    3313.462245
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3209, 5)

# %% [markdown]
# # Spliting the dataset into training (70%) and testing (30%) set

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2246, 7)
# (963, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  292.332886  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  292.410706  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  285.799042  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  277.845703  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  272.167297  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2246   2019-02-07 00:00:00+00:00  1879.133423  2082.899902  2097.949951
# 2247   2019-02-08 00:00:00+00:00  1859.736450  2061.399902  2089.500000
# 2248   2019-02-11 00:00:00+00:00  1863.796143  2065.899902  2096.000000
# 2249   2019-02-12 00:00:00+00:00  1850.895508  2051.600098  2070.000000
# 2250   2019-02-14 00:00:00+00:00  1844.580444  2044.599976  2075.000000
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2246    2067.000000  2074.750000  1339945
# 2247    2051.000000  2075.000000  1684474
# 2248    2048.899902  2060.000000  1778730
# 2249    2018.000000  2070.000000  2422903
# 2250    2033.050049  2060.050049  1724085

# %% [markdown]
# # Using MinMax scaler for normalization of the dataset
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01726447],
#        [0.01658796],
#        [0.01292129],
#        ...,
#        [0.90942911],
#        [0.91213515],
#        [0.91919791]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2146, 100, 1)

# %% [markdown]
# # ML Model (LSTM)
#
# ---

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Attention

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout, Concatenate, Flatten, GlobalAveragePooling1D, Bidirectional

# Input Layer
input_layer = Input(shape=(x_train.shape[1], 1))

# LSTM Layers
lstm1 = Bidirectional(LSTM(units=100, activation='relu', return_sequences=True))(input_layer)
drop1 = Dropout(0.1)(lstm1)

lstm2 = Bidirectional(LSTM(units=120, activation='relu', return_sequences=True))(drop1)
drop2 = Dropout(0.1)(lstm2)

lstm3 = Bidirectional(LSTM(units=150, activation='relu', return_sequences=True))(drop2)
drop3 = Dropout(0.1)(lstm3)

# Attention Layer
class Attention(tf.keras.layers.Layer):
    def call(self, query, value):
        score = tf.matmul(query, value, transpose_b=True)
        weights = tf.nn.softmax(score, axis=-1)
        context = tf.matmul(weights, value)
        return context

attention_layer = Attention()(lstm3, lstm3)  # Self-attention on LSTM output

# Skip Connection: Combine LSTM Outputs with Attention
combined = Concatenate()([lstm3, attention_layer])

# Dimensionality Reduction: Use Global Pooling or Flatten
pooled = GlobalAveragePooling1D()(combined)  # Summarize time steps

# Output Layer
output_layer = Dense(units=1)(pooled)

# Build Model
model = Model(inputs=input_layer, outputs=output_layer)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=1.0)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 100, 1)         │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional             │ (None, 100, 200)       │         81,600 │ input_layer[0][0]      │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 100, 200)       │              0 │ bidirectional[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_1           │ (None, 100, 240)       │        308,160 │ dropout[0][0]          │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 100, 240)       │              0 │ bidirectional_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_2           │ (None, 100, 300)       │        469,200 │ dropout_1[0][0]        │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention (Attention)     │ (None, 100, 300)       │              0 │ bidirectional_2[0][0], │
# │                           │                        │                │ bidirectional_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 100, 600)       │              0 │ bidirectional_2[0][0], │
# │                           │                        │                │ attention[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 600)            │              0 │ concatenate[0][0]      │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1)              │            601 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 859,561 (3.28 MB)
#  Trainable params: 859,561 (3.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model
#
# ---

# %%
# from tensorflow.keras.optimizers import Adam
# model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
import tensorflow as tf
# model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - loss: 0.1078 - mae: 0.2580
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - loss: 0.0026 - mae: 0.0399
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0019 - mae: 0.0320
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0018 - mae: 0.0309
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 0.0018 - mae: 0.0317
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0020 - mae: 0.0322
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - loss: 0.0019 - mae: 0.0313
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0020 - mae: 0.0325
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0018 - mae: 0.0310
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0019 - mae: 0.0322
# Epoch 11/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0018 - mae: 0.0303
# Epoch 12/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0018 - mae: 0.0309
# Epoch 13/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 0.0019 - mae: 0.0317
# Epoch 14/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0017 - mae: 0.0293
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 0.0019 - mae: 0.0313
# Epoch 16/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 89ms/step - loss: 0.0018 - mae: 0.0306
# Epoch 17/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.0017 - mae: 0.0295
# Epoch 18/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0017 - mae: 0.0294
# Epoch 19/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 0.0018 - mae: 0.0305
# Epoch 20/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0016 - mae: 0.0294
# Epoch 21/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - loss: 0.0014 - mae: 0.0273
# Epoch 22/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0014 - mae: 0.0271
# Epoch 23/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - loss: 0.0014 - mae: 0.0267
# Epoch 24/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - loss: 0.0014 - mae: 0.0278
# Epoch 25/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 0.0013 - mae: 0.0260
# Epoch 26/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0012 - mae: 0.0250
# Epoch 27/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0012 - mae: 0.0256
# Epoch 28/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0010 - mae: 0.0232
# Epoch 29/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 9.0582e-04 - mae: 0.0226
# Epoch 30/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0011 - mae: 0.0245
# Epoch 31/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0012 - mae: 0.0251
# Epoch 32/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 7.4120e-04 - mae: 0.0207
# Epoch 33/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 7.4189e-04 - mae: 0.0206
# Epoch 34/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 6.9428e-04 - mae: 0.0199
# Epoch 35/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 6.9215e-04 - mae: 0.0196
# Epoch 36/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 8.7070e-04 - mae: 0.0214
# Epoch 37/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 7.5081e-04 - mae: 0.0205
# Epoch 38/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 8.3278e-04 - mae: 0.0210
# Epoch 39/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 8.4213e-04 - mae: 0.0218
# Epoch 40/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 6.3687e-04 - mae: 0.0183
# Epoch 41/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 8.3844e-04 - mae: 0.0215
# Epoch 42/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 6.2012e-04 - mae: 0.0183
# Epoch 43/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 7.6538e-04 - mae: 0.0210
# Epoch 44/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 5.5945e-04 - mae: 0.0178
# Epoch 45/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 6.7422e-04 - mae: 0.0198
# Epoch 46/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 6.8751e-04 - mae: 0.0192
# Epoch 47/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 5.6578e-04 - mae: 0.0174
# Epoch 48/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 5.1884e-04 - mae: 0.0170
# Epoch 49/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 5.6530e-04 - mae: 0.0180
# Epoch 50/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 5.3259e-04 - mae: 0.0170
# Epoch 51/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 4.2677e-04 - mae: 0.0152
# Epoch 52/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 4.1339e-04 - mae: 0.0152
# Epoch 53/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 4.7240e-04 - mae: 0.0162
# Epoch 54/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 5.7161e-04 - mae: 0.0179
# Epoch 55/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 4.6019e-04 - mae: 0.0158
# Epoch 56/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 4.1254e-04 - mae: 0.0149
# Epoch 57/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 5.8716e-04 - mae: 0.0181
# Epoch 58/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 4.1196e-04 - mae: 0.0148
# Epoch 59/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 4.0908e-04 - mae: 0.0150
# Epoch 60/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 4.1813e-04 - mae: 0.0152
# Epoch 61/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 3.6505e-04 - mae: 0.0143
# Epoch 62/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - loss: 3.8717e-04 - mae: 0.0144
# Epoch 63/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.5847e-04 - mae: 0.0136
# Epoch 64/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 3.5323e-04 - mae: 0.0135
# Epoch 65/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.2887e-04 - mae: 0.0132
# Epoch 66/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.3540e-04 - mae: 0.0136
# Epoch 67/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 3.4318e-04 - mae: 0.0134
# Epoch 68/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 3.4353e-04 - mae: 0.0141
# Epoch 69/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.0769e-04 - mae: 0.0130
# Epoch 70/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 3.5438e-04 - mae: 0.0135
# Epoch 71/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 2.9506e-04 - mae: 0.0127
# Epoch 72/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 4.0204e-04 - mae: 0.0151
# Epoch 73/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 4.0837e-04 - mae: 0.0149
# Epoch 74/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 3.4073e-04 - mae: 0.0132
# Epoch 75/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 2.8455e-04 - mae: 0.0124
# Epoch 76/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 3.2611e-04 - mae: 0.0131
# Epoch 77/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 3.0921e-04 - mae: 0.0130
# Epoch 78/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 3.6720e-04 - mae: 0.0136
# Epoch 79/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 2.7370e-04 - mae: 0.0118
# Epoch 80/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 3.4267e-04 - mae: 0.0135
# Epoch 81/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 2.8379e-04 - mae: 0.0125
# Epoch 82/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 2.6398e-04 - mae: 0.0120
# Epoch 83/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 4.4912e-04 - mae: 0.0160
# Epoch 84/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.2400e-04 - mae: 0.0136
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.9296e-04 - mae: 0.0126
# Epoch 86/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 4.9555e-04 - mae: 0.0165
# Epoch 87/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 5.6906e-04 - mae: 0.0170
# Epoch 88/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 2.8369e-04 - mae: 0.0126
# Epoch 89/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 8.4626e-04 - mae: 0.0214
# Epoch 90/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 3.4189e-04 - mae: 0.0137
# Epoch 91/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 2.6556e-04 - mae: 0.0120
# Epoch 92/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 2.5230e-04 - mae: 0.0115
# Epoch 93/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.9227e-04 - mae: 0.0128
# Epoch 94/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.7153e-04 - mae: 0.0122
# Epoch 95/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 2.4947e-04 - mae: 0.0117
# Epoch 96/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 2.6842e-04 - mae: 0.0121
# Epoch 97/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - loss: 2.6966e-04 - mae: 0.0119
# Epoch 98/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.2836e-04 - mae: 0.0132
# Epoch 99/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.6556e-04 - mae: 0.0121
# Epoch 100/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 3.0274e-04 - mae: 0.0127

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (963, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %% [markdown]
# **Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.**
#
# ---

# %%
# final_df = past_100_days.append(test_df, ignore_index = True)
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2042.199951
# 1  2040.000000
# 2  2018.150024
# 3  2054.550049
# 4  2057.600098

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.21671817],
#        [0.21582892],
#        [0.2069969 ],
#        ...,
#        [0.69522423],
#        [0.69603265],
#        [0.70338929]])

# %%
input_data.shape
# Out:
# (1063, 1)

# %% [markdown]
# # Testing the model
#
# ---

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (963, 100, 1)
# (963,)

# %% [markdown]
# SELAM - Ensure that both the training and testing data are normalized before feeding them into the model:

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# x_train = scaler.fit_transform(x_train.reshape(-1, 1)).reshape(x_train.shape)
# x_test = scaler.transform(x_test.reshape(-1, 1)).reshape(x_test.shape)

# %% [markdown]
# # Making prediction and plotting the graph of predicted vs actual values
#
# ---

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step

# %%
# # Select the last prediction from each sequence
# y_pred_last = y_pred[:, -1, 0]  # Select the last element from the second dimension

# # Inverse transform the selected predictions
# y_pred_inverse = scaler.inverse_transform(y_pred_last.reshape(-1, 1))  # Reshape to 2D for inverse_transform

# # Scale the predictions back to original units
# scale_factor = 1 / scaler.scale_[0]  # Get the scale factor from scaler.scale_
# y_pred_scaled = y_pred_inverse * scale_factor
# y_test_scaled = y_test * scale_factor  # Scale y_test as well

# ... (Rest of the code for plotting and evaluation)

# %%
y_pred.shape
# Out:
# (963, 1)

# %%
y_test
# Out:
# array([0.22674264, 0.22027525, 0.21942637, 0.20693626, 0.21301967,
#        0.20408655, 0.18456314, 0.15600556, 0.15168051, 0.15804685,
#        0.16130073, 0.17156772, 0.18844357, 0.20855311, 0.19060609,
#        0.19171767, 0.19020188, 0.1936175 , 0.19974127, 0.2037228 ,
#        0.20113583, 0.20087308, 0.1910103 , 0.19198042, 0.19602254,
#        0.20410678, 0.1976798 , 0.19966045, 0.19291013, 0.1904444 ,
#        0.18270378, 0.18389618, 0.1886659 , 0.20299519, 0.21461629,
#        0.2231452 , 0.20265162, 0.20725965, 0.21287816, 0.22296322,
#        0.21421207, 0.20517795, 0.20248993, 0.21623313, 0.24636715,
#        0.24582142, 0.25851374, 0.25384507, 0.26275796, 0.26758828,
#        0.27773393, 0.29266964, 0.28498962, 0.25018693, 0.24351744,
#        0.25576508, 0.25236964, 0.25467372, 0.25053055, 0.24883278,
#        0.22890522, 0.23381635, 0.23080499, 0.23603952, 0.21987104,
#        0.2411124 , 0.22997634, 0.21987104, 0.21269628, 0.21586933,
#        0.21784998, 0.23082522, 0.24590225, 0.26120171, 0.27470235,
#        0.27039753, 0.26110065, 0.257099  , 0.27464175, 0.29303339,
#        0.28818285, 0.29790417, 0.29424603, 0.29725739, 0.29311422,
#        0.29794453, 0.28535337, 0.29747973, 0.30103681, 0.30091553,
#        0.30071342, 0.2971968 , 0.28959759, 0.28317066, 0.28715209,
#        0.29343761, 0.29266964, 0.25625011, 0.25305688, 0.24192082,
#        0.22848077, 0.2344429 , 0.23729261, 0.23927321, 0.24008164,
#        0.2368884 , 0.22391316, 0.22492369, 0.22747024, 0.2410517 ,
#        0.23058266, 0.23707028, 0.23806058, 0.24141555, 0.24834775,
#        0.25914019, 0.26686067, 0.26655751, 0.27872433, 0.28513103,
#        0.28343336, 0.28814239, 0.29721703, 0.27819884, 0.26732548,
#        0.2575638 , 0.26340464, 0.26696173, 0.27332806, 0.26837647,
#        0.28612133, 0.29060812, 0.29222497, 0.28697022, 0.28947631,
#        [0.1868878 ],
#        [0.18028389],
#        [0.17660435],
#        [0.17565994],
#        [0.17744349],
#        [0.18266205],
#        [0.18374921],
#        [0.184848  ],
#        [0.18497545],
#        [0.18588705],
#        [0.18816952],
#        [0.19136128],
#        [0.19326222],
#        [0.19436479],
#        [0.19262649],
#        [0.1911778 ],
#        [0.19102032],
#        [0.19267035],
#        [0.19293758],
#        [0.19375929],
#        [0.19284739],
#        [0.1918184 ],
#        [0.18959008],
#        [0.18786395],
#        [0.18743522],
#        [0.18993221],
#        [0.19458736],
#        [0.20074703],
#        [0.20138222],
#        [0.20218426],
#        [0.20414902],
#        [0.2079548 ],
#        [0.20913513],
#        [0.20757101],
#        [0.20559223],
#        [0.20696692],
#        [0.21573676],
#        [0.22370647],
#        [0.23392545],
#        [0.24139601],
#        [0.24906652],
#        [0.2554055 ],
#        [0.26142645],
#        [0.26782447],
#        [0.27161813],
#        [0.26837802],
#        [0.26240653],
#        [0.2582237 ],
#        [0.25349241],
#        [0.24964845],
#        [0.24568738],
#        [0.24213716],
#        [0.23400807],
#        [0.22853236],
#        [0.22416839],
#        [0.22216842],
#        [0.21751152],
#        [0.21884762],
#        [0.2184384 ],
#        [0.21607973],
#        [0.21271838],
#        [0.21123596],
#        [0.2108563 ],
#        [0.21366282],
#        [0.21995296],
#        [0.22917913],
#        [0.24027698],
#        [0.24945368],
#        [0.25493485],
#        [0.25754786],
#        [0.26337564],
#        [0.2725473 ],
#        [0.27923056],
#        [0.28650182],
#        [0.29165268],
#        [0.29602095],
#        [0.29844368],
#        [0.3006789 ],
#        [0.3001989 ],
#        [0.301158  ],
#        [0.30270723],
#        [0.30416924],
#        [0.30546337],
#        [0.305801  ],
#        [0.30452746],
#        [0.30180478],
#        [0.29963243],
#        [0.2989272 ],
#        [0.2983702 ],
#        [0.28971267],
#        [0.27995762],
#        [0.2683556 ],
#        [0.25613797],
#        [0.24873449],
#        [0.2446129 ],
#        [0.24267876],
#        [0.24184035],
#        [0.24107969],
#        [0.23844883],
#        [0.23703714],
#        [0.23687322],
#        [0.23957174],
#        [0.2402265 ],
#        [0.24180765],
#        [0.24349926],
#        [0.24532671],
#        [0.24880043],
#        [0.25433072],
#        [0.2612079 ],
#        [0.26708215],
#        [0.27498975],
#        [0.283497  ],
#        [0.28985113],
#        [0.2957509 ],
#        [0.3024785 ],
#        [0.3029635 ],
#        [0.2992363 ],
#        [0.29138833],
#        [0.28514344],
#        [0.28113365],
#        [0.28017542],
#        [0.27872044],
#        [0.28304   ],
#        [0.28911963],
#        [0.29507136],
#        [0.29809576],
#        [0.30076045],
#        [0.30212772],
#        [0.30495125],
#        [0.3068421 ],
#        [0.3056981 ],
#        [0.30257034],
#        [0.29802695],
#        [0.28990906],
#        [0.279243  ],
#        [0.27026558],
#        [0.26500258],
#        [0.25929865],
#        [0.25623268],
#        [0.2521971 ],
#        [0.24586913],
#        [0.23476428],
#        [0.22959113],
#        [0.22901207],
#        [0.22937717],
#        [0.2292671 ],
#        [0.22986947],
#        [0.22882728],
#        [0.22834466],
#        [0.22875248],
#        [0.22791834],
#        [0.22510237],
#        [0.22152485],
#        [0.2136511 ],
#        [0.2105245 ],
#        [0.21158178],
#        [0.21256164],
#        [0.21222048],
#        [0.21374418],
#        [0.216286  ],
#        [0.21984898],
#        [0.22425093],
#        [0.2295221 ],
#        [0.23753537],
#        [0.24583317],
#        [0.25903988],
#        [0.27857915],
#        [0.2906543 ],
#        [0.2970868 ],
#        [0.2993778 ],
#        [0.3008346 ],
#        [0.30037737],
#        [0.2922057 ],
#        [0.27736387],
#        [0.26908213],
#        [0.2669494 ],
#        [0.26869524],
#        [0.26833066],
#        [0.262098  ],
#        [0.25541645],
#        [0.25168452],
#        [0.24315643],
#        [0.23561473],
#        [0.22855435],
#        [0.22466199],
#        [0.22345515],
#        [0.22155444],
#        [0.21761842],
#        [0.21414445],
#        [0.21448837],
#        [0.217074  ],
#        [0.2229038 ],
#        [0.22392777],
#        [0.21898639],
#        [0.21527822],
#        [0.21061407],
#        [0.20894168],
#        [0.21386588],
#        [0.2226877 ],
#        [0.23492981],
#        [0.24818051],
#        [0.2656879 ],
#        [0.2803363 ],
#        [0.2906754 ],
#        [0.29575872],
#        [0.29710743],
#        [0.2970611 ],
#        [0.29403937],
#        [0.28983298],
#        [0.28468257],
#        [0.28195006],
#        [0.28294003],
#        [0.28404686],
#        [0.28728265],
#        [0.29086798],
#        [0.2937278 ],
#        [0.29355127],
#        [0.29387107],
#        [0.29392362],
#        [0.2958594 ],
#        [0.2974193 ],
#        [0.29323974],
#        [0.2885213 ],
#        [0.28609923],
#        [0.2854848 ],
#        [0.28383666],
#        [0.28189084],
#        [0.27889234],
#        [0.2760406 ],
#        [0.2706892 ],
#        [0.26034713],
#        [0.25453255],
#        [0.25010747],
#        [0.2485633 ],
#        [0.24919635],
#        [0.2503539 ],
#        [0.2515251 ],
#        [0.25565624],
#        [0.25945342],
#        [0.26489058],
#        [0.26968935],
#        [0.27604154],
#        [0.28070134],
#        [0.2843448 ],
#        [0.28267503],
#        [0.27496824],
#        [0.26808932],
#        [0.26268655],
#        [0.2555477 ],
#        [0.24046084],
#        [0.22961316],
#        [0.22499615],
#        [0.22322865],
#        [0.2267254 ],
#        [0.22935542],
#        [0.22180463],
#        [0.21509875],
#        [0.20400901],
#        [0.19058156],
#        [0.18599369],
#        [0.18083164],
#        [0.17633557],
#        [0.17056009],
#        [0.16709404],
#        [0.16348602],
#        [0.15995677],
#        [0.15680943],
#        [0.15432717],
#        [0.1523543 ],
#        [0.15076847],
#        [0.14960982],
#        [0.14650233],
#        [0.14262515],
#        [0.14017576],
#        [0.13760369],
#        [0.1356026 ],
#        [0.13390745],
#        [0.13176161],
#        [0.1281342 ],
#        [0.12705886],
#        [0.12801589],
#        [0.1255413 ],
#        [0.12274059],
#        [0.1221288 ],
#        [0.12413411],
#        [0.12737107],
#        [0.13101433],
#        [0.13638006],
#        [0.14827183],
#        [0.15277359],
#        [0.15631635],
#        [0.15637259],
#        [0.15530995],
#        [0.15428376],
#        [0.15443762],
#        [0.15442967],
#        [0.15510266],
#        [0.15322812],
#        [0.14981191],
#        [0.14708155],
#        [0.14650835],
#        [0.14764667],
#        [0.14895691],
#        [0.15090078],
#        [0.15030147],
#        [0.15049778],
#        [0.15204781],
#        [0.15267636],
#        [0.15405105],
#        [0.15809084],
#        [0.16010143],
#        [0.16289775],
#        [0.16464087],
#        [0.16683422],
#        [0.16835824],
#        [0.16995041],
#        [0.17041911],
#        [0.16757065],
#        [0.16416062],
#        [0.16278638],
#        [0.16135682],
#        [0.16029806],
#        [0.15996008],
#        [0.15900068],
#        [0.15774043],
#        [0.15813734],
#        [0.15726168],
#        [0.15735446],
#        [0.1621145 ],
#        [0.16548617],
#        [0.16862631],
#        [0.17259458],
#        [0.179552  ],
#        [0.18782894],
#        [0.19613028],
#        [0.20196982],
#        [0.20574544],
#        [0.20788977],
#        [0.21094216],
#        [0.2112035 ],
#        [0.21178168],
#        [0.21433137],
#        [0.21523176],
#        [0.21589062],
#        [0.21700625],
#        [0.21716613],
#        [0.21589765],
#        [0.21190572],
#        [0.21089217],
#        [0.21430422],
#        [0.22019224],
#        [0.22743668],
#        [0.23301263],
#        [0.23617183],
#        [0.2381751 ],
#        [0.24135496],
#        [0.24485955],
#        [0.24924128],
#        [0.25233483],
#        [0.25503454],
#        [0.255322  ],
#        [0.25549668],
#        [0.25432175],
#        [0.25359392],
#        [0.25392652],
#        [0.25494048],
#        [0.25539786],
#        [0.25612912],
#        [0.25623637],
#        [0.25678807],
#        [0.256191  ],
#        [0.25804394],
#        [0.2599477 ],
#        [0.26130995],
#        [0.26410595],
#        [0.26699007],
#        [0.27211607],
#        [0.2768325 ],
#        [0.28314564],
#        [0.29186407],
#        [0.2988178 ],
#        [0.30568206],
#        [0.3118953 ],
#        [0.32035232],
#        [0.3324086 ],
#        [0.34393   ],
#        [0.3523143 ],
#        [0.35789767],
#        [0.36211777],
#        [0.3657652 ],
#        [0.36520502],
#        [0.35715306],
#        [0.35144657],
#        [0.34691226],
#        [0.34761262],
#        [0.35150912],
#        [0.35810417],
#        [0.37144396],
#        [0.3871628 ],
#        [0.40520737],
#        [0.42692918],
#        [0.44498444],
#        [0.46155357],
#        [0.4758043 ],
#        [0.485377  ],
#        [0.48844266],
#        [0.48889333],
#        [0.4858282 ],
#        [0.48215333],
#        [0.47421443],
#        [0.46471715],
#        [0.45759976],
#        [0.45169726],
#        [0.444256  ],
#        [0.43692583],
#        [0.43016896],
#        [0.42625606],
#        [0.4228913 ],
#        [0.42094022],
#        [0.42038557],
#        [0.42464092],
#        [0.43083918],
#        [0.43837935],
#        [0.4417312 ],
#        [0.44444084],
#        [0.4474548 ],
#        [0.44814196],
#        [0.45041248],
#        [0.4514128 ],
#        [0.44922003],
#        [0.44848537],
#        [0.44744813],
#        [0.44930416],
#        [0.4543875 ],
#        [0.45850366],
#        [0.46191862],
#        [0.4638534 ],
#        [0.46186003],
#        [0.46462485],
#        [0.46739197],
#        [0.47017908],
#        [0.47326678],
#        [0.47762215],
#        [0.48582822],
#        [0.49287063],
#        [0.49820024],
#        [0.50170094],
#        [0.50357974],
#        [0.50492364],
#        [0.5087738 ],
#        [0.51516396],
#        [0.5168111 ],
#        [0.52003795],
#        [0.5256362 ],
#        [0.53190416],
#        [0.5392799 ],
#        [0.5469797 ],
#        [0.551952  ],
#        [0.5514007 ],
#        [0.551635  ],
#        [0.5554903 ],
#        [0.566364  ],
#        [0.5775922 ],
#        [0.5852389 ],
#        [0.59549415],
#        [0.6102874 ],
#        [0.62352806],
#        [0.6337294 ],
#        [0.64168555],
#        [0.6531837 ],
#        [0.6613454 ],
#        [0.6706997 ],
#        [0.6813455 ],
#        [0.69017327],
#        [0.6956541 ],
#        [0.7016558 ],
#        [0.7029186 ],
#        [0.6996288 ],
#        [0.68937784],
#        [0.673698  ],
#        [0.6653709 ],
#        [0.6591671 ],
#        [0.6564875 ],
#        [0.65339226],
#        [0.6535974 ],
#        [0.65489894],
#        [0.65667397],
#        [0.66108614],
#        [0.6661365 ],
#        [0.6672689 ],
#        [0.6652921 ],
#        [0.658506  ],
#        [0.64973634],
#        [0.6404    ],
#        [0.6261376 ],
#        [0.6154023 ],
#        [0.60319084],
#        [0.5971864 ],
#        [0.586523  ],
#        [0.58008856],
#        [0.57884556],
#        [0.5839079 ],
#        [0.59190184],
#        [0.5994952 ],
#        [0.6061649 ],
#        [0.61176795],
#        [0.621114  ],
#        [0.6283813 ],
#        [0.63451356],
#        [0.64092594],
#        [0.6479847 ],
#        [0.6458309 ],
#        [0.6435369 ],
#        [0.6414571 ],
#        [0.6470627 ],
#        [0.6520631 ],
#        [0.65249795],
#        [0.651741  ],
#        [0.6514405 ],
#        [0.6556708 ],
#        [0.6609247 ],
#        [0.6666875 ],
#        [0.67764074],
#        [0.6885032 ],
#        [0.70004743],
#        [0.7132544 ],
#        [0.71838886],
#        [0.7103854 ],
#        [0.7003971 ],
#        [0.6954784 ],
#        [0.6872555 ],
#        [0.67901725],
#        [0.6711747 ],
#        [0.66285115],
#        [0.654959  ],
#        [0.6499253 ],
#        [0.64742506],
#        [0.6462001 ],
#        [0.6388823 ],
#        [0.6306487 ],
#        [0.6255156 ],
#        [0.62279123],
#        [0.6231715 ],
#        [0.62815547],
#        [0.6350971 ],
#        [0.63929147],
#        [0.64139766],
#        [0.6402135 ],
#        [0.63783795],
#        [0.6383792 ],
#        [0.6382155 ],
#        [0.63720196],
#        [0.63663274],
#        [0.6373306 ],
#        [0.6389099 ],
#        [0.6425671 ],
#        [0.65094835],
#        [0.6574314 ],
#        [0.6628848 ],
#        [0.66765434],
#        [0.66974324],
#        [0.6710778 ],
#        [0.67191553],
#        [0.6730135 ],
#        [0.6776605 ],
#        [0.68229073],
#        [0.68715507],
#        [0.69295484],
#        [0.7020994 ],
#        [0.7093486 ],
#        [0.71573466],
#        [0.72124666],
#        [0.7262998 ],
#        [0.7283341 ],
#        [0.7314396 ],
#        [0.73194474],
#        [0.73296094],
#        [0.7383861 ],
#        [0.7429381 ],
#        [0.74690795],
#        [0.75095624],
#        [0.75359046],
#        [0.75264835],
#        [0.7512428 ],
#        [0.74619883],
#        [0.7395035 ],
#        [0.7318698 ],
#        [0.72227764],
#        [0.7124936 ],
#        [0.70274526],
#        [0.6953672 ],
#        [0.6906926 ],
#        [0.687879  ],
#        [0.68553007],
#        [0.6830092 ],
#        [0.6834661 ],
#        [0.68619645],
#        [0.6884776 ],
#        [0.68907577],
#        [0.6871528 ],
#        [0.6888185 ],
#        [0.6886355 ],
#        [0.6888289 ],
#        [0.693222  ],
#        [0.70109737],
#        [0.7092116 ],
#        [0.71708006],
#        [0.7271335 ],
#        [0.73641545],
#        [0.7449184 ],
#        [0.7519267 ],
#        [0.7596962 ],
#        [0.7708104 ],
#        [0.7825022 ],
#        [0.796961  ],
#        [0.80807126],
#        [0.82053244],
#        [0.8324979 ],
#        [0.8429844 ],
#        [0.8534073 ],
#        [0.8620205 ],
#        [0.8701674 ],
#        [0.87693846],
#        [0.882059  ],
#        [0.8862585 ],
#        [0.8924817 ],
#        [0.8982352 ],
#        [0.90286595],
#        [0.9043725 ],
#        [0.904762  ],
#        [0.90421194],
#        [0.9049849 ],
#        [0.90737844],
#        [0.9109203 ],
#        [0.91158766],
#        [0.9115577 ],
#        [0.91140395],
#        [0.91190946],
#        [0.91193825],
#        [0.9127421 ],
#        [0.9118292 ],
#        [0.9085502 ],
#        [0.90354985],
#        [0.8991635 ],
#        [0.8942949 ],
#        [0.8892847 ],
#        [0.88685834],
#        [0.8882145 ],
#        [0.89220685],
#        [0.90057963],
#        [0.8989951 ],
#        [0.8948946 ],
#        [0.88967556],
#        [0.881684  ],
#        [0.87372136],
#        [0.86777705],
#        [0.8612713 ],
#        [0.8525588 ],
#        [0.84308136],
#        [0.8326428 ],
#        [0.82533324],
#        [0.8202905 ],
#        [0.8138176 ],
#        [0.8073082 ],
#        [0.8032675 ],
#        [0.8039737 ],
#        [0.8062233 ],
#        [0.812017  ],
#        [0.8173303 ],
#        [0.8230246 ],
#        [0.82696897],
#        [0.8275511 ],
#        [0.8296982 ],
#        [0.8334079 ],
#        [0.837838  ],
#        [0.8401411 ],
#        [0.8388421 ],
#        [0.8354316 ],
#        [0.8290795 ],
#        [0.8228314 ],
#        [0.8173129 ],
#        [0.81139874],
#        [0.8059646 ],
#        [0.8059501 ],
#        [0.8099072 ],
#        [0.81738865],
#        [0.8288492 ],
#        [0.8340032 ],
#        [0.837423  ],
#        [0.84301174],
#        [0.8455159 ],
#        [0.8475166 ],
#        [0.849581  ],
#        [0.84995943],
#        [0.84858257],
#        [0.84661394],
#        [0.84464884],
#        [0.8392882 ],
#        [0.8365304 ],
#        [0.83650535],
#        [0.8387864 ],
#        [0.8426652 ],
#        [0.84737533],
#        [0.85401314],
#        [0.85964173],
#        [0.86418617],
#        [0.8702839 ],
#        [0.87600935],
#        [0.8837399 ],
#        [0.890681  ],
#        [0.8949426 ],
#        [0.89892066],
#        [0.9040714 ],
#        [0.90827084],
#        [0.91086316],
#        [0.9134637 ],
#        [0.91546565],
#        [0.9204454 ],
#        [0.92593914],
#        [0.92890626],
#        [0.9274703 ],
#        [0.92300564],
#        [0.9157925 ],
#        [0.9069506 ],
#        [0.8939757 ],
#        [0.88168764],
#        [0.8745081 ],
#        [0.8707505 ],
#        [0.87316364],
#        [0.87888867],
#        [0.88375527],
#        [0.88785565],
#        [0.88961154],
#        [0.8917202 ],
#        [0.89379483],
#        [0.89251906],
#        [0.89172554],
#        [0.8921958 ],
#        [0.8955348 ],
#        [0.8982373 ],
#        [0.90009725],
#        [0.89955556],
#        [0.8922078 ],
#        [0.88259417],
#        [0.86438483],
#        [0.8485434 ],
#        [0.83366233],
#        [0.8239077 ],
#        [0.81934255],
#        [0.8158279 ],
#        [0.81152195],
#        [0.80982214],
#        [0.8167458 ],
#        [0.8261731 ],
#        [0.8353663 ],
#        [0.84354544],
#        [0.8501277 ],
#        [0.8564188 ],
#        [0.8634139 ],
#        [0.8673559 ],
#        [0.8705191 ],
#        [0.8754092 ],
#        [0.8796227 ],
#        [0.8820474 ],
#        [0.8829498 ],
#        [0.8843362 ],
#        [0.8857054 ],
#        [0.8870773 ],
#        [0.888579  ],
#        [0.89024526],
#        [0.89305735],
#        [0.8937112 ],
#        [0.89144427],
#        [0.8865296 ],
#        [0.8812746 ],
#        [0.87548536],
#        [0.8702635 ],
#        [0.8592665 ],
#        [0.8441455 ],
#        [0.83065826],
#        [0.82298505],
#        [0.8189538 ],
#        [0.815947  ],
#        [0.8145348 ],
#        [0.81309694],
#        [0.81393033],
#        [0.815159  ],
#        [0.8146995 ],
#        [0.8128206 ],
#        [0.81162184],
#        [0.80683553],
#        [0.7972527 ],
#        [0.7918321 ],
#        [0.7849979 ],
#        [0.7775127 ],
#        [0.77302235],
#        [0.7692397 ],
#        [0.76596963],
#        [0.7694469 ],
#        [0.76074857],
#        [0.7540249 ],
#        [0.7471828 ],
#        [0.7413834 ],
#        [0.7291648 ],
#        [0.7186338 ],
#        [0.71343327],
#        [0.7144514 ],
#        [0.7204305 ],
#        [0.72981113],
#        [0.7399748 ],
#        [0.7548181 ],
#        [0.76517254],
#        [0.77232456],
#        [0.7765568 ],
#        [0.7789268 ],
#        [0.7795577 ],
#        [0.7687306 ],
#        [0.7543111 ],
#        [0.7406052 ],
#        [0.72284144],
#        [0.6983444 ],
#        [0.6787531 ],
#        [0.6675988 ],
#        [0.6645172 ],
#        [0.66850054],
#        [0.6795481 ],
#        [0.6940603 ],
#        [0.7061674 ],
#        [0.71642745],
#        [0.7236941 ],
#        [0.72817343],
#        [0.7287186 ],
#        [0.7262085 ],
#        [0.722158  ],
#        [0.72144353],
#        [0.72013706],
#        [0.7088402 ],
#        [0.6945613 ],
#        [0.67619735],
#        [0.6532212 ],
#        [0.6303636 ],
#        [0.61592126],
#        [0.6076916 ],
#        [0.60876673],
#        [0.6170064 ],
#        [0.62706333],
#        [0.637771  ],
#        [0.643978  ],
#        [0.6497552 ],
#        [0.660967  ],
#        [0.6763648 ],
#        [0.6910897 ],
#        [0.7044463 ],
#        [0.7157195 ],
#        [0.72620815],
#        [0.7376576 ],
#        [0.7462819 ],
#        [0.7530195 ],
#        [0.7601728 ],
#        [0.7658303 ],
#        [0.77032447],
#        [0.77262896],
#        [0.77311087],
#        [0.7728687 ],
#        [0.7703287 ],
#        [0.7622715 ],
#        [0.7518596 ],
#        [0.7388213 ],
#        [0.7260707 ],
#        [0.7047389 ],
#        [0.68921125],
#        [0.67501366],
#        [0.6639632 ],
#        [0.655734  ],
#        [0.6504086 ],
#        [0.64673215],
#        [0.65005744],
#        [0.65553594],
#        [0.6665363 ],
#        [0.6783137 ],
#        [0.6811029 ],
#        [0.6806179 ],
#        [0.6703681 ],
#        [0.65779054],
#        [0.64868397],
#        [0.63803893],
#        [0.6280182 ],
#        [0.62042344],
#        [0.6100884 ],
#        [0.6053528 ],
#        [0.60316354],
#        [0.6038788 ],
#        [0.60247284],
#        [0.60359114],
#        [0.6086021 ],
#        [0.6194566 ],
#        [0.6274155 ],
#        [0.6308992 ],
#        [0.6363315 ],
#        [0.6415151 ],
#        [0.64460826],
#        [0.6484414 ],
#        [0.65163803],
#        [0.6584217 ],
#        [0.66317916],
#        [0.6664378 ],
#        [0.67046875],
#        [0.6754425 ],
#        [0.6790851 ],
#        [0.6808147 ],
#        [0.6821558 ],
#        [0.68484896],
#        [0.68871844],
#        [0.69363546],
#        [0.6965105 ],
#        [0.6963101 ],
#        [0.6969374 ],
#        [0.69733936],
#        [0.69519067],
#        [0.6988321 ],
#        [0.7070525 ],
#        [0.71435744],
#        [0.72326857],
#        [0.73111004],
#        [0.73749685],
#        [0.738918  ],
#        [0.7373314 ],
#        [0.7366567 ],
#        [0.7364908 ],
#        [0.7389664 ],
#        [0.7432402 ],
#        [0.7489715 ],
#        [0.75379145],
#        [0.76086444],
#        [0.766615  ],
#        [0.7712537 ],
#        [0.77250147],
#        [0.7714854 ],
#        [0.76831955],
#        [0.76024765],
#        [0.7488124 ],
#        [0.7393283 ],
#        [0.73623043],
#        [0.73251706],
#        [0.7256325 ],
#        [0.71754783],
#        [0.7076154 ],
#        [0.70398635],
#        [0.7028455 ],
#        [0.70204014],
#        [0.70339876],
#        [0.70597047],
#        [0.70808905],
#        [0.7106621 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00040421])

# %%
scale_factor = 1 / 0.00041967  # Replace with your scale factor
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# %%
# scale_factor = 1/0.00041967
# y_pred = y_pred_inverse * scale_factor
# y_test = y_test * scale_factor

# %%
# y_pred = np.squeeze(y_pred)
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Calculation of mean absolute error

# %%
from sklearn.metrics import mean_absolute_error

y_pred = y_pred.flatten()
mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 2.36%

# %% [markdown]
# Calculation of R2 score

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9809288806561987

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
