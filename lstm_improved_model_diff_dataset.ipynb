# %% [markdown]
# <a href="https://colab.research.google.com/github/smitike/Stock-Price-Prediction-Using-LSTM/blob/main/lstm_improved_model_diff_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
import yfinance as yf
import pandas as pd

# Define start and end date
START = "2010-01-01"
TODAY = "2023-01-01"

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  295.029663  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  295.108032  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  288.435547  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  280.408722  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  274.677917  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %% [markdown]
# # Define start day to fetch the dataset from the yahoo finance library
#
# ---

# %%
START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

# Define a function to load the dataset

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  289.859131  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  289.936279  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  283.380493  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  275.494507  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  269.864136  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-57-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %% [markdown]
# Visualizing Closing Price

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3204    3252.899902  3272.000000  3225.050049  3228.350098   870157
# 3205    3259.500000  3273.800049  3231.500000  3269.199951   835883
# 3206    3257.100098  3266.100098  3226.000000  3249.800049   910795
# 3207    3268.750000  3271.500000  3228.000000  3231.100098  1037927
# 3208    3256.699951  3299.000000  3246.199951  3286.050049  1163131
#
# [3209 rows x 5 columns]

# %% [markdown]
# # Plotting moving averages of 100 day
#
# ---

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3227.688494
# 3205    3227.295493
# 3206    3226.948494
# 3207    3226.240994
# 3208    3225.258494
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %% [markdown]
# # Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
#
# ---

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3320.515244
# 3205    3318.812994
# 3206    3316.935494
# 3207    3315.174495
# 3208    3313.462245
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3209, 5)

# %% [markdown]
# # Spliting the dataset into training (70%) and testing (30%) set

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2246, 7)
# (963, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  295.029663  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  295.108032  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  288.435547  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  280.408722  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  274.677917  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2246   2019-02-07 00:00:00+00:00  1907.494019  2082.899902  2097.949951
# 2247   2019-02-08 00:00:00+00:00  1887.804321  2061.399902  2089.500000
# 2248   2019-02-11 00:00:00+00:00  1891.925537  2065.899902  2096.000000
# 2249   2019-02-12 00:00:00+00:00  1878.829956  2051.600098  2070.000000
# 2250   2019-02-14 00:00:00+00:00  1872.419312  2044.599976  2075.000000
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2246    2067.000000  2074.750000  1339945
# 2247    2051.000000  2075.000000  1684474
# 2248    2048.899902  2060.000000  1778730
# 2249    2018.000000  2070.000000  2422903
# 2250    2033.050049  2060.050049  1724085

# %% [markdown]
# # Using MinMax scaler for normalization of the dataset
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01726447],
#        [0.01658796],
#        [0.01292129],
#        ...,
#        [0.90942911],
#        [0.91213515],
#        [0.91919791]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2146, 100, 1)

# %% [markdown]
# # ML Model (LSTM)
#
# ---

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model
#
# ---

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 19s 133ms/step - loss: 0.0627 - mean_absolute_error: 0.1818
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 0.0068 - mean_absolute_error: 0.0579
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0064 - mean_absolute_error: 0.0573
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0051 - mean_absolute_error: 0.0517
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0069 - mean_absolute_error: 0.0584
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0049 - mean_absolute_error: 0.0497
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0050 - mean_absolute_error: 0.0499
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0038 - mean_absolute_error: 0.0438
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0039 - mean_absolute_error: 0.0431
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0037 - mean_absolute_error: 0.0431
# Epoch 11/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0034 - mean_absolute_error: 0.0408
# Epoch 12/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0036 - mean_absolute_error: 0.0399
# Epoch 13/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0035 - mean_absolute_error: 0.0422
# Epoch 14/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0040 - mean_absolute_error: 0.0440
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0031 - mean_absolute_error: 0.0391
# Epoch 16/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0031 - mean_absolute_error: 0.0387
# Epoch 17/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0032 - mean_absolute_error: 0.0398
# Epoch 18/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0030 - mean_absolute_error: 0.0389
# Epoch 19/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0030 - mean_absolute_error: 0.0382
# Epoch 20/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0031 - mean_absolute_error: 0.0383
# Epoch 21/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0024 - mean_absolute_error: 0.0356
# Epoch 22/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0033 - mean_absolute_error: 0.0406
# Epoch 23/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0066 - mean_absolute_error: 0.0570
# Epoch 24/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0032 - mean_absolute_error: 0.0396
# Epoch 25/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0354
# Epoch 26/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0037 - mean_absolute_error: 0.0446
# Epoch 27/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0022 - mean_absolute_error: 0.0345
# Epoch 28/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0025 - mean_absolute_error: 0.0356
# Epoch 29/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0023 - mean_absolute_error: 0.0351
# Epoch 30/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0022 - mean_absolute_error: 0.0341
# Epoch 31/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0328
# Epoch 32/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0022 - mean_absolute_error: 0.0357
# Epoch 33/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0022 - mean_absolute_error: 0.0337
# Epoch 34/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0021 - mean_absolute_error: 0.0340
# Epoch 35/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0019 - mean_absolute_error: 0.0330
# Epoch 36/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0021 - mean_absolute_error: 0.0335
# Epoch 37/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0334
# Epoch 38/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0355
# Epoch 39/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0018 - mean_absolute_error: 0.0310
# Epoch 40/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0020 - mean_absolute_error: 0.0333
# Epoch 41/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0019 - mean_absolute_error: 0.0329
# Epoch 42/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0020 - mean_absolute_error: 0.0331
# Epoch 43/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0318
# Epoch 44/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0322
# Epoch 45/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0019 - mean_absolute_error: 0.0323
# Epoch 46/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0017 - mean_absolute_error: 0.0312
# Epoch 47/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0332
# Epoch 48/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0018 - mean_absolute_error: 0.0315
# Epoch 49/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0018 - mean_absolute_error: 0.0308
# Epoch 50/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0017 - mean_absolute_error: 0.0315
# Epoch 51/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0019 - mean_absolute_error: 0.0335
# Epoch 52/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0020 - mean_absolute_error: 0.0327
# Epoch 53/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0020 - mean_absolute_error: 0.0331
# Epoch 54/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0018 - mean_absolute_error: 0.0315
# Epoch 55/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0015 - mean_absolute_error: 0.0298
# Epoch 56/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0016 - mean_absolute_error: 0.0302
# Epoch 57/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0316
# Epoch 58/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0302
# Epoch 59/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0018 - mean_absolute_error: 0.0321
# Epoch 60/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0018 - mean_absolute_error: 0.0319
# Epoch 61/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0025 - mean_absolute_error: 0.0366
# Epoch 62/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0016 - mean_absolute_error: 0.0302
# Epoch 63/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0019 - mean_absolute_error: 0.0324
# Epoch 64/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0314
# Epoch 65/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0019 - mean_absolute_error: 0.0322
# Epoch 66/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0021 - mean_absolute_error: 0.0331
# Epoch 67/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0015 - mean_absolute_error: 0.0292
# Epoch 68/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0015 - mean_absolute_error: 0.0286
# Epoch 69/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0016 - mean_absolute_error: 0.0305
# Epoch 70/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0016 - mean_absolute_error: 0.0297
# Epoch 71/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0348
# Epoch 72/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0020 - mean_absolute_error: 0.0344
# Epoch 73/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0017 - mean_absolute_error: 0.0312
# Epoch 74/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0305
# Epoch 75/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0019 - mean_absolute_error: 0.0318
# Epoch 76/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0016 - mean_absolute_error: 0.0304
# Epoch 77/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0018 - mean_absolute_error: 0.0308
# Epoch 78/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0018 - mean_absolute_error: 0.0310
# Epoch 79/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0018 - mean_absolute_error: 0.0308
# Epoch 80/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0016 - mean_absolute_error: 0.0301
# Epoch 81/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0018 - mean_absolute_error: 0.0327
# Epoch 82/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0323
# Epoch 83/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0018 - mean_absolute_error: 0.0309
# Epoch 84/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0016 - mean_absolute_error: 0.0296
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0017 - mean_absolute_error: 0.0306
# Epoch 86/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0019 - mean_absolute_error: 0.0316
# Epoch 87/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0016 - mean_absolute_error: 0.0303
# Epoch 88/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0018 - mean_absolute_error: 0.0309
# Epoch 89/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0019 - mean_absolute_error: 0.0323
# Epoch 90/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0018 - mean_absolute_error: 0.0312
# Epoch 91/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0019 - mean_absolute_error: 0.0313
# Epoch 92/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0020 - mean_absolute_error: 0.0326
# Epoch 93/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0018 - mean_absolute_error: 0.0316
# Epoch 94/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0015 - mean_absolute_error: 0.0295
# Epoch 95/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0015 - mean_absolute_error: 0.0290
# Epoch 96/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0015 - mean_absolute_error: 0.0289
# Epoch 97/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0017 - mean_absolute_error: 0.0298
# Epoch 98/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0016 - mean_absolute_error: 0.0303
# Epoch 99/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0017 - mean_absolute_error: 0.0302
# Epoch 100/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0303

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (963, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %% [markdown]
# **Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.**
#
# ---

# %%
# final_df = past_100_days.append(test_df, ignore_index = True)
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2042.199951
# 1  2040.000000
# 2  2018.150024
# 3  2054.550049
# 4  2057.600098

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.21671817],
#        [0.21582892],
#        [0.2069969 ],
#        ...,
#        [0.69522423],
#        [0.69603265],
#        [0.70338929]])

# %%
input_data.shape
# Out:
# (1063, 1)

# %% [markdown]
# # Testing the model
#
# ---

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (963, 100, 1)
# (963,)

# %% [markdown]
# # Making prediction and plotting the graph of predicted vs actual values
#
# ---

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step

# %%
y_pred.shape
# Out:
# (963, 1)

# %%
y_test
# Out:
# array([0.22674264, 0.22027525, 0.21942637, 0.20693626, 0.21301967,
#        0.20408655, 0.18456314, 0.15600556, 0.15168051, 0.15804685,
#        0.16130073, 0.17156772, 0.18844357, 0.20855311, 0.19060609,
#        0.19171767, 0.19020188, 0.1936175 , 0.19974127, 0.2037228 ,
#        0.20113583, 0.20087308, 0.1910103 , 0.19198042, 0.19602254,
#        0.20410678, 0.1976798 , 0.19966045, 0.19291013, 0.1904444 ,
#        0.71406054, 0.71341377, 0.70694638, 0.70575397, 0.69484025,
#        0.68752397, 0.6856242 , 0.71100872, 0.70492532, 0.6467188 ,
#        0.63631035, 0.61801976, 0.59053335, 0.58487438, 0.60965259,
#        0.61601893, 0.64350534, 0.66209909, 0.66187675, 0.66414038,
#        0.64287879, 0.64833565, 0.68538163, 0.71503061, 0.71341377,
#        0.71367646, 0.71585927, 0.72810691, 0.74736757, 0.73968754,
#        0.73928333, 0.75547203, 0.75797813, 0.76050445, 0.75387542,
#        0.75019705, 0.75393601, 0.74429552, 0.71300955, 0.70500614,
#        0.69067685, 0.6915055 , 0.63661351, 0.66131089, 0.65278198,
#        0.65249905, 0.64924513, 0.64686032, 0.64510196, 0.66858671,
#        0.67198205, 0.69482002, 0.69482002, 0.64987168, 0.64429353,
#        0.60387234, 0.59894098, 0.6159987 , 0.60312451, 0.59550518,
#        0.59538389, 0.57400112, 0.59417126, 0.5957881 , 0.59983022,
#        0.58370221, 0.59336283, 0.61316922, 0.64124171, 0.62735709,
#        0.6058934 , 0.62543709, 0.62895371, 0.62503287, 0.63257139,
#        0.63275326, 0.6558338 , 0.64914407, 0.64631459, 0.65520725,
#        0.66652519, 0.66496893, 0.65817825, 0.66248307, 0.67574124,
#        0.68610923, 0.69362761, 0.68269366, 0.67103211, 0.68273412,
#        0.68538163, 0.67258836, 0.70696661, 0.72877382, 0.72190222,
#        0.73380624, 0.73231067, 0.73362436, 0.71422219, 0.70704743,
#        0.721498  , 0.72849089, 0.74453808, 0.75163202, 0.7586855 ,
#        0.7554518 , 0.77364134, 0.77081186, 0.76838658, 0.75262232,
#        0.74696335, 0.74108205, 0.71557634, 0.69930681, 0.71212031,
#        0.74166814, 0.72471147, 0.69490084, 0.68249156, 0.67002158,
#        0.7008832 , 0.70294472, 0.69158632, 0.69484025, 0.6974474 ,
#        0.69522423, 0.69603265, 0.70338929])

# %%
y_pred
# Out:
# array([[0.21598348],
#        [0.2200757 ],
#        [0.22439702],
#        [0.22876027],
#        [0.23294574],
#        [0.23676416],
#        [0.2400412 ],
#        [0.24257115],
#        [0.24410115],
#        [0.24443266],
#        [0.24352226],
#        [0.24148475],
#        [0.23866901],
#        [0.23562476],
#        [0.23302385],
#        [0.23120698],
#        [0.23025188],
#        [0.23001762],
#        [0.23036608],
#        [0.23117752],
#        [0.23233747],
#        [0.23371616],
#        [0.23522924],
#        [0.23671992],
#        [0.23803604],
#        [0.23908669],
#        [0.23988092],
#        [0.24044016],
#        [0.24081083],
#        [0.24101037],
#        [0.24104297],
#        [0.2408974 ],
#        [0.24057263],
#        [0.2401104 ],
#        [0.23964193],
#        [0.23935235],
#        [0.23942128],
#        [0.23985547],
#        [0.24063028],
#        [0.24167587],
#        [0.24294691],
#        [0.24434312],
#        [0.24570428],
#        [0.24686548],
#        [0.24776596],
#        [0.24857596],
#        [0.24949935],
#        [0.2507481 ],
#        [0.2524759 ],
#        [0.2549339 ],
#        [0.25823465],
#        [0.2623631 ],
#        [0.26723197],
#        [0.27270097],
#        [0.27854037],
#        [0.28452367],
#        [0.29037204],
#        [0.2957513 ],
#        [0.3005912 ],
#        [0.30468118],
#        [0.30790055],
#        [0.31000054],
#        [0.3108068 ],
#        [0.31028408],
#        [0.30847266],
#        [0.30538535],
#        [0.3013112 ],
#        [0.29661196],
#        [0.2915268 ],
#        [0.286278  ],
#        [0.28107688],
#        [0.2761176 ],
#        [0.27158245],
#        [0.26777512],
#        [0.2649585 ],
#        [0.26326552],
#        [0.26282552],
#        [0.2637837 ],
#        [0.26602423],
#        [0.26938996],
#        [0.2736701 ],
#        [0.27868617],
#        [0.28418463],
#        [0.28995174],
#        [0.2956898 ],
#        [0.30125958],
#        [0.30665368],
#        [0.31184325],
#        [0.3167259 ],
#        [0.32121432],
#        [0.3252109 ],
#        [0.3288118 ],
#        [0.33206677],
#        [0.33500034],
#        [0.33764264],
#        [0.3400696 ],
#        [0.3422558 ],
#        [0.34420735],
#        [0.34591147],
#        [0.34734425],
#        [0.3484506 ],
#        [0.3491474 ],
#        [0.3492986 ],
#        [0.34868914],
#        [0.34723443],
#        [0.3448593 ],
#        [0.34151876],
#        [0.33720297],
#        [0.3317327 ],
#        [0.32525077],
#        [0.3180105 ],
#        [0.3105319 ],
#        [0.30322298],
#        [0.29644474],
#        [0.29044527],
#        [0.28540117],
#        [0.28147334],
#        [0.2788359 ],
#        [0.27758104],
#        [0.27775162],
#        [0.27926132],
#        [0.28191504],
#        [0.28559974],
#        [0.29005432],
#        [0.29488242],
#        [0.29983348],
#        [0.30474848],
#        [0.3094527 ],
#        [0.31387702],
#        [0.3179711 ],
#        [0.3216478 ],
#        [0.32488123],
#        [0.32778546],
#        [0.33043808],
#        [0.3328905 ],
#        [0.33517045],
#        [0.33728027],
#        [0.33931127],
#        [0.3412827 ],
#        [0.3431372 ],
#        [0.34481698],
#        [0.34632185],
#        [0.34761658],
#        [0.3486346 ],
#        [0.3493253 ],
#        [0.34967157],
#        [0.34952664],
#        [0.34876284],
#        [0.3472902 ],
#        [0.34486946],
#        [0.34114832],
#        [0.33590698],
#        [0.32916394],
#        [0.3211149 ],
#        [0.31226444],
#        [0.30335122],
#        [0.29482943],
#        [0.28705025],
#        [0.28026837],
#        [0.27453363],
#        [0.2696493 ],
#        [0.26545364],
#        [0.2616635 ],
#        [0.25808728],
#        [0.25478923],
#        [0.25187832],
#        [0.24940032],
#        [0.24740148],
#        [0.24594799],
#        [0.24508041],
#        [0.24483486],
#        [0.24522716],
#        [0.24626157],
#        [0.24790779],
#        [0.2502455 ],
#        [0.253511  ],
#        [0.257698  ],
#        [0.26272875],
#        [0.26840982],
#        [0.2745231 ],
#        [0.28086013],
#        [0.28719023],
#        [0.29314998],
#        [0.29851946],
#        [0.30317357],
#        [0.30707797],
#        [0.31029534],
#        [0.31274515],
#        [0.31428063],
#        [0.3148166 ],
#        [0.31424266],
#        [0.31239313],
#        [0.30913275],
#        [0.30453992],
#        [0.29900572],
#        [0.29289517],
#        [0.2865216 ],
#        [0.28018758],
#        [0.2742808 ],
#        [0.26906952],
#        [0.26482895],
#        [0.26159644],
#        [0.25914165],
#        [0.25721583],
#        [0.25557253],
#        [0.25403565],
#        [0.2526732 ],
#        [0.25170794],
#        [0.25140622],
#        [0.25196636],
#        [0.25349772],
#        [0.25612894],
#        [0.25985608],
#        [0.26457778],
#        [0.2700752 ],
#        [0.27608722],
#        [0.28236416],
#        [0.28866813],
#        [0.2946704 ],
#        [0.30021727],
#        [0.30532056],
#        [0.30995828],
#        [0.31422544],
#        [0.31819332],
#        [0.32183382],
#        [0.3251016 ],
#        [0.32806015],
#        [0.3307353 ],
#        [0.33317378],
#        [0.33541   ],
#        [0.33742103],
#        [0.33924296],
#        [0.34090015],
#        [0.34236997],
#        [0.3436446 ],
#        [0.3447078 ],
#        [0.34555885],
#        [0.34619683],
#        [0.34652486],
#        [0.34634638],
#        [0.34545875],
#        [0.34373146],
#        [0.34110478],
#        [0.33767086],
#        [0.33345047],
#        [0.32869342],
#        [0.32369816],
#        [0.31881443],
#        [0.3146429 ],
#        [0.311643  ],
#        [0.3100231 ],
#        [0.3096955 ],
#        [0.31047213],
#        [0.31208187],
#        [0.31420577],
#        [0.31654492],
#        [0.31876257],
#        [0.32045656],
#        [0.32098472],
#        [0.3198375 ],
#        [0.3166277 ],
#        [0.3114748 ],
#        [0.30511072],
#        [0.298195  ],
#        [0.2909296 ],
#        [0.2835343 ],
#        [0.27584887],
#        [0.26715964],
#        [0.2571413 ],
#        [0.24571186],
#        [0.23314217],
#        [0.21979265],
#        [0.2063805 ],
#        [0.19362563],
#        [0.18212456],
#        [0.17236519],
#        [0.16465287],
#        [0.15905845],
#        [0.15544415],
#        [0.1535545 ],
#        [0.1528522 ],
#        [0.15273567],
#        [0.15281956],
#        [0.15284885],
#        [0.15277667],
#        [0.1526739 ],
#        [0.15257777],
#        [0.15237996],
#        [0.15220027],
#        [0.15228799],
#        [0.15261243],
#        [0.15306103],
#        [0.15362662],
#        [0.15442881],
#        [0.15559396],
#        [0.15719327],
#        [0.15918475],
#        [0.16175562],
#        [0.16493782],
#        [0.1686962 ],
#        [0.1728814 ],
#        [0.17721127],
#        [0.18141022],
#        [0.18531677],
#        [0.18884532],
#        [0.1920135 ],
#        [0.19477604],
#        [0.19703308],
#        [0.19873351],
#        [0.1999772 ],
#        [0.20099652],
#        [0.20203996],
#        [0.20334974],
#        [0.20495561],
#        [0.20683993],
#        [0.20900172],
#        [0.21134022],
#        [0.21383163],
#        [0.21654737],
#        [0.21948704],
#        [0.22264232],
#        [0.22599688],
#        [0.2295475 ],
#        [0.23319255],
#        [0.23681915],
#        [0.24032241],
#        [0.24353087],
#        [0.24623325],
#        [0.24825615],
#        [0.24956982],
#        [0.25021735],
#        [0.25031483],
#        [0.24999139],
#        [0.249363  ],
#        [0.24858643],
#        [0.24775875],
#        [0.24696729],
#        [0.24643874],
#        [0.24633494],
#        [0.24673879],
#        [0.24767855],
#        [0.24922663],
#        [0.251545  ],
#        [0.25483268],
#        [0.2590744 ],
#        [0.26418144],
#        [0.2699419 ],
#        [0.27613398],
#        [0.28253594],
#        [0.2889328 ],
#        [0.29507896],
#        [0.30085903],
#        [0.30630288],
#        [0.31141382],
#        [0.31615406],
#        [0.32044056],
#        [0.3241177 ],
#        [0.32725272],
#        [0.32994744],
#        [0.33232757],
#        [0.33451384],
#        [0.33655405],
#        [0.33851436],
#        [0.3404668 ],
#        [0.34236294],
#        [0.3441458 ],
#        [0.34580493],
#        [0.34735027],
#        [0.34876677],
#        [0.35005605],
#        [0.35119933],
#        [0.35221156],
#        [0.35311663],
#        [0.3539342 ],
#        [0.35466003],
#        [0.3553087 ],
#        [0.35590053],
#        [0.35643336],
#        [0.3568994 ],
#        [0.3572959 ],
#        [0.35763147],
#        [0.35791466],
#        [0.35815275],
#        [0.35835823],
#        [0.35853934],
#        [0.35871136],
#        [0.3588843 ],
#        [0.35907495],
#        [0.35931057],
#        [0.35960433],
#        [0.35995963],
#        [0.36037317],
#        [0.36088705],
#        [0.36159712],
#        [0.36262804],
#        [0.3640666 ],
#        [0.36589563],
#        [0.3680582 ],
#        [0.37049186],
#        [0.37293836],
#        [0.37504888],
#        [0.37666422],
#        [0.37775648],
#        [0.378439  ],
#        [0.37890974],
#        [0.3794392 ],
#        [0.3807596 ],
#        [0.3845744 ],
#        [0.39330524],
#        [0.40820724],
#        [0.42756125],
#        [0.44898254],
#        [0.46995205],
#        [0.4876828 ],
#        [0.49954364],
#        [0.5053331 ],
#        [0.50632626],
#        [0.50410783],
#        [0.49970168],
#        [0.4939917 ],
#        [0.48807484],
#        [0.48268503],
#        [0.4778582 ],
#        [0.47340783],
#        [0.46915218],
#        [0.465262  ],
#        [0.46175635],
#        [0.45866138],
#        [0.45610768],
#        [0.45524117],
#        [0.45664066],
#        [0.4601187 ],
#        [0.4641708 ],
#        [0.46763474],
#        [0.47023946],
#        [0.47169697],
#        [0.47231483],
#        [0.47233924],
#        [0.47131062],
#        [0.469561  ],
#        [0.4674816 ],
#        [0.46596864],
#        [0.4661242 ],
#        [0.467856  ],
#        [0.47057223],
#        [0.47335848],
#        [0.47497562],
#        [0.47604978],
#        [0.47717676],
#        [0.47857273],
#        [0.4802763 ],
#        [0.48254457],
#        [0.4862865 ],
#        [0.49135885],
#        [0.4967513 ],
#        [0.50131404],
#        [0.50439733],
#        [0.5060162 ],
#        [0.5072275 ],
#        [0.509467  ],
#        [0.5119885 ],
#        [0.5145991 ],
#        [0.5180118 ],
#        [0.52271724],
#        [0.5287548 ],
#        [0.535834  ],
#        [0.5427556 ],
#        [0.5472078 ],
#        [0.5490694 ],
#        [0.5502585 ],
#        [0.55413467],
#        [0.5619328 ],
#        [0.5718326 ],
#        [0.58312273],
#        [0.5971154 ],
#        [0.6132016 ],
#        [0.62857676],
#        [0.6407751 ],
#        [0.6514002 ],
#        [0.66047394],
#        [0.6689898 ],
#        [0.67805076],
#        [0.68726563],
#        [0.6951183 ],
#        [0.7017727 ],
#        [0.7058437 ],
#        [0.7059018 ],
#        [0.70025957],
#        [0.6890776 ],
#        [0.6762798 ],
#        [0.66579217],
#        [0.66025496],
#        [0.6588415 ],
#        [0.6606734 ],
#        [0.6647277 ],
#        [0.66952246],
#        [0.67462665],
#        [0.6793953 ],
#        [0.6818491 ],
#        [0.6805174 ],
#        [0.67448074],
#        [0.6645138 ],
#        [0.6521983 ],
#        [0.63803524],
#        [0.6236009 ],
#        [0.60963225],
#        [0.59799147],
#        [0.5879427 ],
#        [0.57952857],
#        [0.57388395],
#        [0.5725727 ],
#        [0.5760346 ],
#        [0.5826082 ],
#        [0.5900631 ],
#        [0.59647596],
#        [0.60260105],
#        [0.60818064],
#        [0.61272764],
#        [0.6164084 ],
#        [0.6199822 ],
#        [0.62102544],
#        [0.6191924 ],
#        [0.6155853 ],
#        [0.6140713 ],
#        [0.61626834],
#        [0.62006557],
#        [0.623325  ],
#        [0.62548304],
#        [0.6284833 ],
#        [0.63351786],
#        [0.6404994 ],
#        [0.650614  ],
#        [0.6631635 ],
#        [0.6771424 ],
#        [0.69191736],
#        [0.7031764 ],
#        [0.705343  ],
#        [0.6988099 ],
#        [0.688577  ],
#        [0.67766356],
#        [0.6680156 ],
#        [0.6602799 ],
#        [0.6543553 ],
#        [0.650035  ],
#        [0.6475395 ],
#        [0.64701074],
#        [0.6479333 ],
#        [0.64729905],
#        [0.64354795],
#        [0.63782483],
#        [0.63200223],
#        [0.6279508 ],
#        [0.62741745],
#        [0.6308027 ],
#        [0.63611007],
#        [0.6407175 ],
#        [0.6424532 ],
#        [0.64085335],
#        [0.63776124],
#        [0.63444525],
#        [0.6313081 ],
#        [0.6286644 ],
#        [0.62713194],
#        [0.6271529 ],
#        [0.6291487 ],
#        [0.6343907 ],
#        [0.64175004],
#        [0.6492307 ],
#        [0.6554134 ],
#        [0.6591294 ],
#        [0.6604483 ],
#        [0.6600471 ],
#        [0.6589613 ],
#        [0.6594248 ],
#        [0.6621972 ],
#        [0.6669733 ],
#        [0.67323184],
#        [0.68165815],
#        [0.69099826],
#        [0.6997032 ],
#        [0.7068279 ],
#        [0.7123419 ],
#        [0.71567726],
#        [0.71781045],
#        [0.71865284],
#        [0.71900535],
#        [0.7213913 ],
#        [0.7259431 ],
#        [0.7315185 ],
#        [0.7372131 ],
#        [0.7420722 ],
#        [0.74458885],
#        [0.7447218 ],
#        [0.74195737],
#        [0.7366108 ],
#        [0.7296128 ],
#        [0.72159034],
#        [0.7132757 ],
#        [0.70530736],
#        [0.69869506],
#        [0.69430673],
#        [0.69225335],
#        [0.6916903 ],
#        [0.69125795],
#        [0.6911863 ],
#        [0.69203824],
#        [0.69334096],
#        [0.69374037],
#        [0.69192445],
#        [0.68947953],
#        [0.6868634 ],
#        [0.6845195 ],
#        [0.68413496],
#        [0.68731344],
#        [0.69373333],
#        [0.7018493 ],
#        [0.7111189 ],
#        [0.7205261 ],
#        [0.72917396],
#        [0.7361911 ],
#        [0.74196386],
#        [0.74876076],
#        [0.7575853 ],
#        [0.76947474],
#        [0.7820385 ],
#        [0.7945343 ],
#        [0.8065329 ],
#        [0.81732327],
#        [0.8270498 ],
#        [0.83534163],
#        [0.8426198 ],
#        [0.84912777],
#        [0.85472226],
#        [0.8594935 ],
#        [0.8652307 ],
#        [0.872152  ],
#        [0.8791776 ],
#        [0.8840911 ],
#        [0.8864527 ],
#        [0.886788  ],
#        [0.88713264],
#        [0.88926   ],
#        [0.89378095],
#        [0.8979801 ],
#        [0.90049803],
#        [0.9014523 ],
#        [0.90195787],
#        [0.90228915],
#        [0.9029503 ],
#        [0.9030403 ],
#        [0.90133035],
#        [0.8974509 ],
#        [0.8928048 ],
#        [0.8882549 ],
#        [0.8842    ],
#        [0.8817326 ],
#        [0.8822851 ],
#        [0.8861114 ],
#        [0.8935008 ],
#        [0.89782685],
#        [0.8963169 ],
#        [0.8899672 ],
#        [0.880357  ],
#        [0.86960906],
#        [0.8603326 ],
#        [0.85317004],
#        [0.8469349 ],
#        [0.84071046],
#        [0.8338425 ],
#        [0.8272667 ],
#        [0.82206523],
#        [0.81720614],
#        [0.8116512 ],
#        [0.80604905],
#        [0.8025054 ],
#        [0.8016564 ],
#        [0.8039119 ],
#        [0.8077116 ],
#        [0.8118298 ],
#        [0.8148751 ],
#        [0.8151733 ],
#        [0.81384236],
#        [0.81298757],
#        [0.81380653],
#        [0.8153309 ],
#        [0.8153758 ],
#        [0.81312346],
#        [0.80831623],
#        [0.8022343 ],
#        [0.7965291 ],
#        [0.79179865],
#        [0.78823745],
#        [0.7879922 ],
#        [0.7923882 ],
#        [0.8012776 ],
#        [0.81379926],
#        [0.82462996],
#        [0.8311213 ],
#        [0.83481264],
#        [0.8361065 ],
#        [0.8358575 ],
#        [0.83545583],
#        [0.8350326 ],
#        [0.83424133],
#        [0.83338857],
#        [0.83287287],
#        [0.8314339 ],
#        [0.8301296 ],
#        [0.8306085 ],
#        [0.8336704 ],
#        [0.838965  ],
#        [0.84536535],
#        [0.8524179 ],
#        [0.858909  ],
#        [0.8637679 ],
#        [0.86772704],
#        [0.87132293],
#        [0.87597305],
#        [0.88151175],
#        [0.8861361 ],
#        [0.8894645 ],
#        [0.8928065 ],
#        [0.8963568 ],
#        [0.8993727 ],
#        [0.90182245],
#        [0.90376085],
#        [0.90720963],
#        [0.9126659 ],
#        [0.91771924],
#        [0.9191542 ],
#        [0.9159497 ],
#        [0.90880644],
#        [0.8994257 ],
#        [0.88820755],
#        [0.8771009 ],
#        [0.8695897 ],
#        [0.8674898 ],
#        [0.8715984 ],
#        [0.8802575 ],
#        [0.88940865],
#        [0.8960599 ],
#        [0.8985396 ],
#        [0.89760655],
#        [0.8948209 ],
#        [0.8902068 ],
#        [0.8849294 ],
#        [0.880955  ],
#        [0.8803926 ],
#        [0.88272107],
#        [0.8860791 ],
#        [0.8880216 ],
#        [0.88514113],
#        [0.8772551 ],
#        [0.86341166],
#        [0.8464771 ],
#        [0.829715  ],
#        [0.81712395],
#        [0.81130767],
#        [0.81107783],
#        [0.8127983 ],
#        [0.8147334 ],
#        [0.8192164 ],
#        [0.8266728 ],
#        [0.835006  ],
#        [0.84182   ],
#        [0.8460164 ],
#        [0.8482053 ],
#        [0.85000074],
#        [0.85096127],
#        [0.85116327],
#        [0.85229963],
#        [0.85492325],
#        [0.85803986],
#        [0.8605365 ],
#        [0.86261314],
#        [0.86471057],
#        [0.8671535 ],
#        [0.8699328 ],
#        [0.87289095],
#        [0.87640786],
#        [0.87931126],
#        [0.8799439 ],
#        [0.87747705],
#        [0.87295616],
#        [0.8677125 ],
#        [0.863152  ],
#        [0.85734993],
#        [0.84839386],
#        [0.83778197],
#        [0.8295177 ],
#        [0.82586265],
#        [0.82592875],
#        [0.8277323 ],
#        [0.8294375 ],
#        [0.8308768 ],
#        [0.8319243 ],
#        [0.83145225],
#        [0.8287074 ],
#        [0.8245609 ],
#        [0.818726  ],
#        [0.81010073],
#        [0.8010739 ],
#        [0.7927691 ],
#        [0.78529286],
#        [0.7797191 ],
#        [0.7761445 ],
#        [0.7738801 ],
#        [0.774699  ],
#        [0.7732393 ],
#        [0.76846105],
#        [0.76110935],
#        [0.75290155],
#        [0.7424966 ],
#        [0.73078895],
#        [0.7205098 ],
#        [0.71493644],
#        [0.7159685 ],
#        [0.72302485],
#        [0.7336106 ],
#        [0.74695647],
#        [0.7594931 ],
#        [0.7682191 ],
#        [0.7719836 ],
#        [0.7715381 ],
#        [0.7683321 ],
#        [0.7601032 ],
#        [0.74711293],
#        [0.7319147 ],
#        [0.7158861 ],
#        [0.6985818 ],
#        [0.6814481 ],
#        [0.6675229 ],
#        [0.6602389 ],
#        [0.66132617],
#        [0.67082995],
#        [0.68673056],
#        [0.7040422 ],
#        [0.71868324],
#        [0.7281733 ],
#        [0.7321127 ],
#        [0.7307869 ],
#        [0.7252216 ],
#        [0.71714246],
#        [0.7101113 ],
#        [0.7057958 ],
#        [0.70067954],
#        [0.6927476 ],
#        [0.6814569 ],
#        [0.6668961 ],
#        [0.6502348 ],
#        [0.6340525 ],
#        [0.6213025 ],
#        [0.6149945 ],
#        [0.61667585],
#        [0.62539244],
#        [0.638404  ],
#        [0.65058184],
#        [0.6592243 ],
#        [0.66622204],
#        [0.6747198 ],
#        [0.68513525],
#        [0.6961256 ],
#        [0.7061283 ],
#        [0.71483594],
#        [0.72324264],
#        [0.7307835 ],
#        [0.73678076],
#        [0.74201685],
#        [0.74693   ],
#        [0.7516228 ],
#        [0.7554326 ],
#        [0.7578006 ],
#        [0.75900364],
#        [0.7588686 ],
#        [0.7557415 ],
#        [0.7493626 ],
#        [0.7400805 ],
#        [0.7295152 ],
#        [0.7163967 ],
#        [0.70255834],
#        [0.6896454 ],
#        [0.67908025],
#        [0.6714515 ],
#        [0.666592  ],
#        [0.66386354],
#        [0.6641084 ],
#        [0.6673327 ],
#        [0.67408   ],
#        [0.68319   ],
#        [0.6894779 ],
#        [0.69030106],
#        [0.6836422 ],
#        [0.6710567 ],
#        [0.6556378 ],
#        [0.6397244 ],
#        [0.6250019 ],
#        [0.6127733 ],
#        [0.6025331 ],
#        [0.59508866],
#        [0.590835  ],
#        [0.58970153],
#        [0.5899186 ],
#        [0.5907098 ],
#        [0.5928358 ],
#        [0.5981804 ],
#        [0.6057778 ],
#        [0.61234736],
#        [0.617282  ],
#        [0.6208087 ],
#        [0.6229378 ],
#        [0.62431395],
#        [0.6253735 ],
#        [0.62784743],
#        [0.6317503 ],
#        [0.6361613 ],
#        [0.64080125],
#        [0.6460757 ],
#        [0.65163636],
#        [0.6563487 ],
#        [0.65985924],
#        [0.66308945],
#        [0.66717863],
#        [0.6727318 ],
#        [0.67847174],
#        [0.68245304],
#        [0.6847797 ],
#        [0.68611366],
#        [0.68610686],
#        [0.6872373 ],
#        [0.6920643 ],
#        [0.70006955],
#        [0.71022344],
#        [0.7206174 ],
#        [0.729659  ],
#        [0.73508906],
#        [0.7360146 ],
#        [0.7341759 ],
#        [0.7317983 ],
#        [0.7313311 ],
#        [0.7339686 ],
#        [0.7396707 ],
#        [0.7469016 ],
#        [0.75519824],
#        [0.7633339 ],
#        [0.7700294 ],
#        [0.77361315],
#        [0.773582  ],
#        [0.7703929 ],
#        [0.7638016 ],
#        [0.75396264],
#        [0.74318635],
#        [0.7355069 ],
#        [0.73182356],
#        [0.7296579 ],
#        [0.72662294],
#        [0.7213132 ],
#        [0.7160374 ],
#        [0.7125964 ],
#        [0.7108224 ],
#        [0.7103598 ],
#        [0.71086526],
#        [0.7117213 ],
#        [0.71249527]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00040421])

# %%
scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Calculation of mean absolute error

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 7.30%

# %% [markdown]
# Calculation of R2 score

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9638117755842558

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
